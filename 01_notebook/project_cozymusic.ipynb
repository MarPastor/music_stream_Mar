# %% [markdown]
# ## Stream Music project
#
# Stream Music is a music data analytics project, extracting information from the Spotify and Last.fm APIs to explore listener behavior and trends in music genres, artists, and songs between 2020 and 2022
#
# ### Phase 1: Data Extraction
#
# In this phase, information is collected from external sources:
#
# - Spotify API: Relevant information is extracted about artists, songs, musical genres, type (song or album), song name, release year, etc.
#
# - Last.fm API: Additional information is obtained such as artist biographies, popularity and streaming statistics, similar artists, etc.
#
# - Storage: The collected data is processed and stored in structured CSV files, which will serve as a source for subsequent upload to the database
#
# ---

# %% [markdown]
# ## Data Extraction: Spotify API
# ---
#
# The Spotify API is used to request information about songs, genres, and artists over a defined period of time.
#
# Spotify's API requires authentication using `API keys`, access tokens that you can obtain from the API documentation available here:
# [Spotify Web API](https://developer.spotify.com/documentation/web-api)

# %%
# the 'spotipy' library must be install, which serves as a bridge between the Spotify API and the notebook

# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\maryl\anaconda3\lib\site-packages (2.25.1)
# Requirement already satisfied: redis>=3.5.3 in c:\users\maryl\anaconda3\lib\site-packages (from spotipy) (6.2.0)
# Requirement already satisfied: requests>=2.25.0 in c:\users\maryl\anaconda3\lib\site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\maryl\anaconda3\lib\site-packages (from spotipy) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\maryl\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maryl\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maryl\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2025.6.15)

# %%
# import the libraries needed for data extraction

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time
import pandas as pd
import requests
from bs4 import BeautifulSoup

# import the libraries needed to connect to SQL to create the database and perform queries in MySQL

import pandas as pd
import mysql.connector
from mysql.connector import errorcode

# %%
# after reviewing the Spotify API documentation, the Client_ID and Client_Secret are used

CLIENT_ID = 'e72fce80a01a461cbc184eae381f0700' # replace with 'insert your Client_ID here'
CLIENT_SECRET = 'cc179290604c436c8b35a324eb91f00b' # replace with 'insert your Client_Secret here'

# we start the Spotify API authentication

auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
# for the extraction sample we selected 4 genres and the range of years

genres = ['pop', 'rock', 'jazz', 'r&b']
start_year = 2020
finish_year = 2022

# %%
# a function is defined for the extraction of songs with the parameters: genres, start_year, finish_year, and offsets)

artists = [] # empty list defined as an external variable to be used in the extraction using the Last.fm API

def extraction_songs(genres, start_year, finish_year, offsets):
    results = [] # empty lists as local variables
    offsets = 0
    
    for genre in genres:
        for i in range(start_year, finish_year):
            for offsets in range(0,150,50): # a sample of 150 songs is selected per year
                data = sp.search(q=f"genre:{genre}, year:{i}", type='track', limit=50, offset=offsets)
                print(f'Retriving year {i} and offset {offsets}') # print that controls to shows what information is being extracted
                len(data)
                for item in data["tracks"]["items"]:
                    results.append({
                    'artist':item['artists'][0]['name'],
                    'genre':genre,
                    'song_name':item['name'],
                    'release_year':item['album']['release_date'][:4],
                    'id_song':item['id']})
                    artists.append(item['artists'][0]['name'])
    
    df = pd.DataFrame(results)
    print(f'format data frame songs: {df.shape}')
    df.to_csv(f'../03_data/songs.csv') # a CSV file is created with the song information

    set_artists = set(artists)
    dfa = pd.DataFrame(set_artists)
    print(f'format data frame artists: {dfa.shape}')
    dfa.to_csv(f'../03_data/artists.csv') # a CSV file is created with the artist information we used in the extraction with the Last.fm API

    return results, set_artists

# %%
# the function is called by altering the desired parameters

extraction_songs(genres,2020,2022,0)
# Out:
# Retriving year 2020 and offset 0
# Retriving year 2020 and offset 50
# Retriving year 2020 and offset 100
# Retriving year 2021 and offset 0
# Retriving year 2021 and offset 50
# Retriving year 2021 and offset 100
# Retriving year 2020 and offset 0
# Retriving year 2020 and offset 50
# Retriving year 2020 and offset 100
# Retriving year 2021 and offset 0
# Retriving year 2021 and offset 50
# Retriving year 2021 and offset 100
# Retriving year 2020 and offset 0
# Retriving year 2020 and offset 50
# Retriving year 2020 and offset 100
# Retriving year 2021 and offset 0
# Retriving year 2021 and offset 50
# Retriving year 2021 and offset 100
# Retriving year 2020 and offset 0
# Retriving year 2020 and offset 50
# Retriving year 2020 and offset 100
# Retriving year 2021 and offset 0
# Retriving year 2021 and offset 50
# Retriving year 2021 and offset 100
# format data frame songs: (1200, 5)
# format data frame artists: (624, 1)
# ([{'artist': 'Charli xcx',
#    'genre': 'pop',
#    'song_name': 'party 4 u',
#    'release_year': '2020',
#    'id_song': '2RdEC8Ff83WkX7kDVCHseE'},
#   {'artist': 'Joel Corry',
#    'genre': 'pop',
#    'song_name': 'Head & Heart (feat. MNEK)',
#    'release_year': '2020',
#    'id_song': '6cx06DFPPHchuUAcTxznu9'},
#   {'artist': 'Ava Max',
#    'genre': 'pop',
#    'song_name': 'Kings & Queens',
#    'release_year': '2020',
#    'id_song': '7a53HqqArd4b9NF4XAmlbI'},
#   {'artist': 'Ava Max',
#    'genre': 'pop',
#    'song_name': 'Sweet but Psycho',
#    'release_year': '2020',
#    'id_song': '7DnAm9FOTWE3cUvso43HhI'},
#   {'artist': 'Dua Lipa',
#    'genre': 'pop',
#    'song_name': "Don't Start Now",
#    'release_year': '2020',
#    'id_song': '3PfIrDoz19wz7qK7tYeu62'},
#   {'artist': 'Dua Lipa',
#    'genre': 'pop',
#    'song_name': 'Levitating (feat. DaBaby)',
#    'release_year': '2020',
#    'id_song': '5nujrmhLynf4yMoMtj8AQF'},
#   {'artist': 'Olivia Dean',
#    'genre': 'pop',
#    'song_name': 'Echo',
#    'release_year': '2020',
#    'id_song': '1Gy9Ofi7nPnNf3kGWPjurm'},
#   {'artist': 'SAULT',
#    'genre': 'pop',
#    'song_name': 'Wildfires',
#    'release_year': '2020',
#    'id_song': '4Tzw9IdZbVyzmpWrvsGaNX'},
#   {'artist': 'The Weeknd',
#    'genre': 'pop',
#    'song_name': 'Save Your Tears (Remix) (with Ariana Grande) - Bonus Track',
#    'release_year': '2020',
#    'id_song': '1oFAF1hdPOickyHgbuRjyX'},
#   {'artist': 'Kygo',
#    'genre': 'pop',
#    'song_name': 'Higher Love',
#    'release_year': '2020',
#    'id_song': '1kKYjjfNYxE0YYgLa7vgVY'},
#   {'artist': 'Wizkid',
#    'genre': 'pop',
#    'song_name': 'Essence (feat. Tems)',
#    'release_year': '2020',
#    'id_song': '5FG7Tl93LdH117jEKYl3Cm'},
#   {'artist': 'VOILÀ',
#    'genre': 'pop',
#    'song_name': 'Figure You Out',
#    'release_year': '2020',
#    'id_song': '2bFGGsScXp2Tu10jKMCKO6'},
#   {'artist': 'YUNGBLUD',
#    'genre': 'pop',
#    'song_name': 'parents',
#    'release_year': '2020',
#    'id_song': '5v4OkFH0TJ6W1hCFxyn0px'},
#   {'artist': 'Dua Lipa',
#    'genre': 'pop',
#    'song_name': 'Physical',
#    'release_year': '2020',
#    'id_song': '3AzjcOeAmA57TIOr9zF1ZW'},
#   {'artist': 'THE ANXIETY',
#    'genre': 'pop',
#    'song_name': 'Meet Me At Our Spot',
#    'release_year': '2020',
#    'id_song': '07MDkzWARZaLEdKxo6yArG'},
#   {'artist': 'Ariana Grande',
#    'genre': 'pop',
#    'song_name': 'positions',
#    'release_year': '2020',
#    'id_song': '35mvY5S1H3J2QZyna3TFe0'},
#   {'artist': 'Lady Gaga',
#    'genre': 'pop',
#    'song_name': 'Rain On Me (with Ariana Grande)',
#    'release_year': '2020',
#    'id_song': '7ju97lgwC2rKQ6wwsf9no9'},
#   {'artist': 'Dua Lipa',
#    'genre': 'pop',
#    'song_name': 'Love Again',
#    'release_year': '2020',
#    'id_song': '4rPkN1FMzQyFNP9cLUGIIB'},
#   {'artist': 'BTS',
#    'genre': 'pop',
#    'song_name': 'Dynamite',
#    'release_year': '2020',
#    'id_song': '5QDLhrAOJJdNAmCTJ8xMyW'},
#   {'artist': 'Magdalena Bay',
#    'genre': 'pop',
#    'song_name': 'Killshot',
#    'release_year': '2020',
#    'id_song': '0LJTfmgOMvlLd0u4HU9twm'},
#   {'artist': 'Conan Gray',
#    'genre': 'pop',
#    'song_name': 'Maniac',
#    'release_year': '2020',
#    'id_song': '6KfoDhO4XUWSbnyKjNp9c4'},
#   {'artist': 'Stray Kids',
#    'genre': 'pop',
#    'song_name': 'God’s Menu',
#    'release_year': '2020',
#    'id_song': '4XPXrcpyNr30Km6aPiflJy'},
#   {'artist': 'mgk',
#    'genre': 'pop',
#    'song_name': "my ex's best friend (with blackbear)",
#    'release_year': '2020',
#    'id_song': '7kDUspsoYfLkWnZR7qwHZl'},
#   {'artist': 'JAWNY',
#    'genre': 'pop',
#    'song_name': 'Honeypie',
#    'release_year': '2020',
#    'id_song': '6FfLg6FFqhCsrFOaHIGkg0'},
#   {'artist': 'BLACKPINK',
#    'genre': 'pop',
#    'song_name': 'How You Like That',
#    'release_year': '2020',
#    'id_song': '4SFknyjLcyTLJFPKD2m96o'},
#   {'artist': 'Dua Lipa',
#    'genre': 'pop',
#    'song_name': 'Break My Heart',
#    'release_year': '2020',
#    'id_song': '017PF4Q3l4DBUiWoXk4OWT'},
#   {'artist': 'Forest Blakk',
#    'genre': 'pop',
#    'song_name': 'If You Love Her',
#    'release_year': '2020',
#    'id_song': '727Z2S2mtNH46CbP9EWPwY'},
#   {'artist': 'Ellie Goulding',
#    'genre': 'pop',
#    'song_name': 'Lights',
#    'release_year': '2020',
#    'id_song': '0LRCcpSgeozipxPpRg5wzx'},
#   {'artist': 'Ava Max',
#    'genre': 'pop',
#    'song_name': 'My Head & My Heart',
#    'release_year': '2020',
#    'id_song': '1KixkQVDUHggZMU9dUobgm'},
#   {'artist': 'Joel Corry',
#    'genre': 'pop',
#    'song_name': 'Lonely',
#    'release_year': '2020',
#    'id_song': '2ZEq4HT450Ye9IFGPTl9qV'},
#   {'artist': 'Miley Cyrus',
#    'genre': 'pop',
#    'song_name': 'Midnight Sky',
#    'release_year': '2020',
#    'id_song': '4i2qxFEVVUi8yOYoxB8TCX'},
#   {'artist': 'Beach Bunny',
#    'genre': 'pop',
#    'song_name': 'Cloud 9',
#    'release_year': '2020',
#    'id_song': '3ZgkHyoKfNMcHTXC0X1qQj'},
#   {'artist': 'Katy Perry',
#    'genre': 'pop',
#    'song_name': 'Harleys In Hawaii',
#    'release_year': '2020',
#    'id_song': '3B4etxytImrRKQgV3XHjnR'},
#   {'artist': 'Jung Kook',
#    'genre': 'pop',
#    'song_name': 'Still With You',
#    'release_year': '2020',
#    'id_song': '0eFMbKCRw8KByXyWBw8WO7'},
#   {'artist': 'Ariana Grande',
#    'genre': 'pop',
#    'song_name': '34+35',
#    'release_year': '2020',
#    'id_song': '6Im9k8u9iIzKMrmV7BWtlF'},
#   {'artist': 'Black Eyed Peas',
#    'genre': 'pop',
#    'song_name': 'GIRL LIKE ME',
#    'release_year': '2020',
#    'id_song': '1zLBsSVxETQOfINOLYvT5m'},
#   {'artist': 'mgk',
#    'genre': 'pop',
#    'song_name': 'forget me too (feat. Halsey)',
#    'release_year': '2020',
#    'id_song': '1VSuFS7PahCN3SWbOcQ98m'},
#   {'artist': 'Jonasu',
#    'genre': 'pop',
#    'song_name': 'Black Magic',
#    'release_year': '2020',
#    'id_song': '7zx1i0jGcFwMBurajgKlO7'},
#   {'artist': 'Diplo',
#    'genre': 'pop',
#    'song_name': 'Heartless (feat. Morgan Wallen)',
#    'release_year': '2020',
#    'id_song': '3FU6urUVsgXa6RBuV2PdRk'},
#   {'artist': 'The Weeknd',
#    'genre': 'pop',
#    'song_name': 'In Your Eyes',
#    'release_year': '2020',
#    'id_song': '7szuecWAPwGoV1e5vGu8tl'},
#   {'artist': 'mgk',
#    'genre': 'pop',
#    'song_name': 'bloody valentine',
#    'release_year': '2020',
#    'id_song': '6mADjHs6FXdroPzEGW6KVJ'},
#   {'artist': 'Halsey',
#    'genre': 'pop',
#    'song_name': 'You should be sad',
#    'release_year': '2020',
#    'id_song': '7lidXGPXPYLNThITAOTlkK'},
#   {'artist': 'Regard',
#    'genre': 'pop',
#    'song_name': 'Secrets',
#    'release_year': '2020',
#    'id_song': '66W1rVTnEv86dIkFhoiElg'},
#   {'artist': 'Miley Cyrus',
#    'genre': 'pop',
#    'song_name': 'Prisoner (feat. Dua Lipa)',
#    'release_year': '2020',
#    'id_song': '2Oycxb8QbPkpHTo8ZrmG0B'},
#   {'artist': 'Dua Lipa',
#    'genre': 'pop',
#    'song_name': 'Hallucinate',
#    'release_year': '2020',
#    'id_song': '1nYeVF5vIBxMxfPoL0SIWg'},
#   {'artist': 'Shane Codd',
#    'genre': 'pop',
#    'song_name': 'Get Out My Head',
#    'release_year': '2020',
#    'id_song': '055Mme9ReKK99jRFA5UJ55'},
#   {'artist': 'Sam Hunt',
#    'genre': 'pop',
#    'song_name': 'Body Like A Back Road',
#    'release_year': '2020',
#    'id_song': '7FpBQ067pHB67deawpbbcY'},
#   {'artist': 'BLACKPINK',
#    'genre': 'pop',
#    'song_name': 'Pretty Savage',
#    'release_year': '2020',
#    'id_song': '1XnpzbOGptRwfJhZgLbmSr'},
#   {'artist': 'BLACKPINK',
#    'genre': 'pop',
#    'song_name': 'Lovesick Girls',
#    'release_year': '2020',
#    'id_song': '4Ws314Ylb27BVsvlZOy30C'},
#   {'artist': 'Dean Blunt',
#    'genre': 'pop',
#    'song_name': '9',
#    'release_year': '2020',
#    'id_song': '5JXtkWtuqS8Dm8sKbtPGWa'},
#   {'artist': 'Ariana Grande',
#    'genre': 'pop',
#    'song_name': 'motive (with Doja Cat)',
#    'release_year': '2020',
#    'id_song': '5GkQIP5mWPi4KZLLXeuFTT'},
#   {'artist': 'Cigarettes After Sex',
#    'genre': 'pop',
#    'song_name': "You're All I Want",
#    'release_year': '2020',
#    'id_song': '2cTvZSCqzjkTMkIypLxUFH'},
#   {'artist': 'All Time Low',
#    'genre': 'pop',
#    'song_name': 'Monsters (feat. blackbear)',
#    'release_year': '2020',
#    'id_song': '0tyR7Bu9P086aWBFZ4QJoo'},
#   {'artist': 'YUNGBLUD',
#    'genre': 'pop',
#    'song_name': 'acting like that (feat. Machine Gun Kelly)',
#    'release_year': '2020',
#    'id_song': '1Pv3rDsjRl98xEQC56p8A0'},
#   {'artist': 'Lady Gaga',
#    'genre': 'pop',
#    'song_name': 'Rain On Me (with Ariana Grande)',
#    'release_year': '2020',
#    'id_song': '24ySl2hOPGCDcxBxFIqWBu'},
#   {'artist': 'Ariana Grande',
#    'genre': 'pop',
#    'song_name': 'pov',
#    'release_year': '2020',
#    'id_song': '3UoULw70kMsiVXxW0L3A33'},
#   {'artist': 'Fujii Kaze',
#    'genre': 'pop',
#    'song_name': 'Shinunoga E-Wa',
#    'release_year': '2020',
#    'id_song': '0o9zmvc5f3EFApU52PPIyW'},
#   {'artist': 'Billie Eilish',
#    'genre': 'pop',
#    'song_name': 'Therefore I Am',
#    'release_year': '2020',
#    'id_song': '54bFM56PmE4YLRnqpW6Tha'},
#   {'artist': 'Selena Gomez',
#    'genre': 'pop',
#    'song_name': 'People You Know',
#    'release_year': '2020',
#    'id_song': '63mdJr3NMY3wReOkNE6c6W'},
#   {'artist': 'Biig Piig',
#    'genre': 'pop',
#    'song_name': 'Feels Right',
#    'release_year': '2020',
#    'id_song': '0BWBqb5XxraObLopqskk6D'},
#   {'artist': 'Little Mix',
#    'genre': 'pop',
#    'song_name': 'Sweet Melody',
#    'release_year': '2020',
#    'id_song': '76Tuo484SLohJakHLnGI3B'},
#   {'artist': 'Lewis Capaldi',
#    'genre': 'pop',
#    'song_name': 'Before You Go - Guitar Acoustic',
#    'release_year': '2020',
#    'id_song': '27829SWtwhWUANViVTEpol'},
#   {'artist': 'Sigala',
#    'genre': 'pop',
#    'song_name': 'Lasting Lover',
#    'release_year': '2020',
#    'id_song': '0DmAvNCAK08oCi7miSZUIY'},
#   {'artist': 'Ed Sheeran',
#    'genre': 'pop',
#    'song_name': 'Afterglow',
#    'release_year': '2020',
#    'id_song': '0E4Y1XIbs8GrAT1YqVy6dq'},
#   {'artist': 'Lee Brice',
#    'genre': 'pop',
#    'song_name': 'One Of Them Girls',
#    'release_year': '2020',
#    'id_song': '6uyiyatWPCqC59Mm4rO8xL'},
#   {'artist': 'Olivia Dean',
#    'genre': 'pop',
#    'song_name': 'What Am I Gonna Do On Sundays?',
#    'release_year': '2020',
#    'id_song': '0WttB2xYS66VopJmwD1UzF'},
#   {'artist': 'Stray Kids',
#    'genre': 'pop',
#    'song_name': 'Back Door',
#    'release_year': '2020',
#    'id_song': '0XuepwFJUcKN8T5zTqoP0F'},
#   {'artist': 'Wande Coal',
#    'genre': 'pop',
#    'song_name': 'Again',
#    'release_year': '2020',
#    'id_song': '6qk3jI8bKCgURI3h0d8zBZ'},
#   {'artist': 'Olivia Dean',
#    'genre': 'pop',
#    'song_name': 'Crosswords',
#    'release_year': '2020',
#    'id_song': '094OGVJzllUzmdLvA31GqU'},
#   {'artist': 'Clean Bandit',
#    'genre': 'pop',
#    'song_name': 'Tick Tock (feat. 24kGoldn)',
#    'release_year': '2020',
#    'id_song': '27u7t9d7ZQoyjsCROHuZJ3'},
#   {'artist': 'Billie Eilish',
#    'genre': 'pop',
#    'song_name': 'my future',
#    'release_year': '2020',
#    'id_song': '2ygvZOXrIeVL4xZmAWJT2C'},
#   {'artist': 'Alexander 23',
#    'genre': 'pop',
#    'song_name': 'IDK You Yet',
#    'release_year': '2020',
#    'id_song': '0j1Ia2lQWrcXrQZI4AdJlk'},
#   {'artist': 'Tate McRae',
#    'genre': 'pop',
#    'song_name': 'stupid',
#    'release_year': '2020',
#    'id_song': '0gIxF0RR0miqWLs2fPQGBu'},
#   {'artist': 'Conan Gray',
#    'genre': 'pop',
#    'song_name': 'Wish You Were Sober',
#    'release_year': '2020',
#    'id_song': '0kn2gu8Pd03DiYHzRvX2Xk'},
#   {'artist': 'Forest Blakk',
#    'genre': 'pop',
#    'song_name': 'Fall Into Me',
#    'release_year': '2020',
#    'id_song': '5AWVGdsk88fcsrssrAdyEN'},
#   {'artist': 'Sir Chloe',
#    'genre': 'pop',
#    'song_name': 'Michelle',
#    'release_year': '2020',
#    'id_song': '6XrTwqp0vMc2Z3m4ttoyRe'},
#   {'artist': 'Shawn Mendes',
#    'genre': 'pop',
#    'song_name': 'Wonder',
#    'release_year': '2020',
#    'id_song': '6ZuahEctZD6w75peme58hm'},
#   {'artist': 'Zoe Wees',
#    'genre': 'pop',
#    'song_name': 'Control',
#    'release_year': '2020',
#    'id_song': '50Td3qilgs8BLtv8mHyT1t'},
#   {'artist': 'Remi Wolf',
#    'genre': 'pop',
#    'song_name': 'Disco Man',
#    'release_year': '2020',
#    'id_song': '0T7aTl1t15HKHfwep4nANV'},
#   {'artist': 'Katy Perry',
#    'genre': 'pop',
#    'song_name': 'Never Really Over',
#    'release_year': '2020',
#    'id_song': '1IIV8jglA0klVZy17q665k'},
#   {'artist': 'YUNGBLUD',
#    'genre': 'pop',
#    'song_name': 'cotton candy',
#    'release_year': '2020',
#    'id_song': '5lVZiDONIcGowIOetTZ4ps'},
#   {'artist': 'ENHYPEN',
#    'genre': 'pop',
#    'song_name': 'Given-Taken',
#    'release_year': '2020',
#    'id_song': '69WpV0U7OMNFGyq8I63dcC'},
#   {'artist': 'Lady Gaga',
#    'genre': 'pop',
#    'song_name': 'Stupid Love',
#    'release_year': '2020',
#    'id_song': '7yBbV2k2S2uhaQc24NF2xt'},
#   {'artist': 'K/DA',
#    'genre': 'pop',
#    'song_name': 'VILLAIN',
#    'release_year': '2020',
#    'id_song': '3QSjVPObHxuAJc3E5nrjRn'},
#   {'artist': 'Ariana Grande',
#    'genre': 'pop',
#    'song_name': 'safety net (feat. Ty Dolla $ign)',
#    'release_year': '2020',
#    'id_song': '14gkWVFMwdxBMyqBw1wmIg'},
#   {'artist': 'mgk',
#    'genre': 'pop',
#    'song_name': 'drunk face',
#    'release_year': '2020',
#    'id_song': '3k0YJnqMKRZb8swo86vCkq'},
#   {'artist': 'YUNGBLUD',
#    'genre': 'pop',
#    'song_name': 'mars',
#    'release_year': '2020',
#    'id_song': '6C6aknFp2XtjIq7xuvyfuY'},
#   {'artist': 'Fiona Apple',
#    'genre': 'pop',
#    'song_name': 'I Want You To Love Me',
#    'release_year': '2020',
#    'id_song': '73SBAGI4fPFm4VkB3NjXq8'},
#   {'artist': 'melvitto',
#    'genre': 'pop',
#    'song_name': 'Trouble',
#    'release_year': '2020',
#    'id_song': '5yplb3035SZqG3E6TArvGK'},
#   {'artist': 'The 1975',
#    'genre': 'pop',
#    'song_name': 'Me & You Together Song',
#    'release_year': '2020',
#    'id_song': '6SrvijeageGUiFu9iCDdmM'},
#   {'artist': 'Shawn Mendes',
#    'genre': 'pop',
#    'song_name': 'Wonder',
#    'release_year': '2020',
#    'id_song': '5KCbr5ndeby4y4ggthdiAb'},
#   {'artist': 'mgk',
#    'genre': 'pop',
#    'song_name': 'body bag (feat. YUNGBLUD & Bert McCracken of The Used)',
#    'release_year': '2020',
#    'id_song': '0NZrY7Lc9g6V03hxRpfToV'},
#   {'artist': 'Black Eyed Peas',
#    'genre': 'pop',
#    'song_name': 'RITMO (Bad Boys For Life)',
#    'release_year': '2020',
#    'id_song': '5NyS3oxTlos3Agl2YtZwrC'},
#   {'artist': 'AP Dhillon',
#    'genre': 'pop',
#    'song_name': 'Excuses',
#    'release_year': '2020',
#    'id_song': '29m79w9xPMH4YCD6r8JSmV'},
#   {'artist': 'TWICE',
#    'genre': 'pop',
#    'song_name': "I CAN'T STOP ME",
#    'release_year': '2020',
#    'id_song': '37ZtpRBkHcaq6hHy0X98zn'},
#   {'artist': 'Tiësto',
#    'genre': 'pop',
#    'song_name': 'Ritual',
#    'release_year': '2020',
#    'id_song': '0FEk8LwY8h4rAR63ggfhV0'},
#   {'artist': 'Miley Cyrus',
#    'genre': 'pop',
#    'song_name': 'Edge of Midnight (Midnight Sky Remix) (feat. Stevie Nicks)',
#    'release_year': '2020',
#    'id_song': '1Tip6R4swhC7E6hgILBjrE'},
#   {'artist': 'Charli xcx',
#    'genre': 'pop',
#    'song_name': 'claws',
#    'release_year': '2020',
#    'id_song': '7Dexi5Z2IowCkHrnzlWysc'},
#   {'artist': 'Dua Lipa',
#    'genre': 'pop',
#    'song_name': 'Levitating (feat. DaBaby)',
#    'release_year': '2020',
#    'id_song': '463CkQjx2Zk1yXoBuierM9'},
#   {'artist': 'Oracle Sisters',
#    'genre': 'pop',
#    'song_name': 'Asc. Scorpio',
#    'release_year': '2020',
#    'id_song': '2MnSPY2QYMbtkDWGzY02In'},
#   {'artist': 'Khalid',
#    'genre': 'pop',
#    'song_name': 'Know Your Worth (feat. Davido & Tems)',
#    'release_year': '2020',
#    'id_song': '04QTmCTsaVjcGaoxj8rSjE'},
#   {'artist': 'Omah Lay',
#    'genre': 'pop',
#    'song_name': 'Godly',
#    'release_year': '2020',
#    'id_song': '6NgjdJrK7Bpyvsm8yDtx4H'},
#   {'artist': 'RAYE',
#    'genre': 'pop',
#    'song_name': 'Regardless',
#    'release_year': '2020',
#    'id_song': '3DTqHfTGj1c6y2gDXsTez4'},
#   {'artist': 'Sam Smith',
#    'genre': 'pop',
#    'song_name': 'How Do You Sleep?',
#    'release_year': '2020',
#    'id_song': '34pRqzRiFcIuyRMuuEayzY'},
#   {'artist': 'Grimes',
#    'genre': 'pop',
#    'song_name': '4ÆM',
#    'release_year': '2020',
#    'id_song': '4keclC0eBhQm8lFtYmX01K'},
#   {'artist': 'Joji',
#    'genre': 'pop',
#    'song_name': 'Sanctuary',
#    'release_year': '2020',
#    'id_song': '4VQH4VluDUOsOuDxccTeyN'},
#   {'artist': 'LAUREL',
#    'genre': 'pop',
#    'song_name': 'Scream Drive Faster',
#    'release_year': '2020',
#    'id_song': '4hEpfRem37hLFT8ldr78Mx'},
#   {'artist': 'Keith Urban',
#    'genre': 'pop',
#    'song_name': 'One Too Many',
#    'release_year': '2020',
#    'id_song': '5NUXE8W12lWcUXgJRCjeEw'},
#   {'artist': 'L.A.X',
#    'genre': 'pop',
#    'song_name': 'Sempe',
#    'release_year': '2020',
#    'id_song': '7AbLGIOzFkx6jHq5en5xiH'},
#   {'artist': 'Jax Jones',
#    'genre': 'pop',
#    'song_name': 'i miss u (with Au/Ra)',
#    'release_year': '2020',
#    'id_song': '7CH8J4ulT49UfZwSDSkSZA'},
#   {'artist': 'Loona',
#    'genre': 'pop',
#    'song_name': 'Vamos a la Playa',
#    'release_year': '2020',
#    'id_song': '2Tk5B1h58lJRsrivGg1jaE'},
#   {'artist': 'twocolors',
#    'genre': 'pop',
#    'song_name': 'Lovefool',
#    'release_year': '2020',
#    'id_song': '51Of5p3lKZeOg6itfs4og4'},
#   {'artist': 'Hot Mulligan',
#    'genre': 'pop',
#    'song_name': '*Equip Sunglasses*',
#    'release_year': '2020',
#    'id_song': '427OHPoIWqO3SsFw77EkDf'},
#   {'artist': 'Wizkid',
#    'genre': 'pop',
#    'song_name': 'Blessed (feat. Damian Marley)',
#    'release_year': '2020',
#    'id_song': '3QO1m6i0nsrp8aOnapvbkx'},
#   {'artist': 'BTS',
#    'genre': 'pop',
#    'song_name': 'Life Goes On',
#    'release_year': '2020',
#    'id_song': '5FVbvttjEvQ8r2BgUcJgNg'},
#   {'artist': 'Dua Lipa',
#    'genre': 'pop',
#    'song_name': 'Pretty Please',
#    'release_year': '2020',
#    'id_song': '6DXZiYUbrYgrVIhfX3U9Z2'},
#   {'artist': 'SAULT',
#    'genre': 'pop',
#    'song_name': 'Son Shine',
#    'release_year': '2020',
#    'id_song': '2Ohu1ERZnAuaCzi7N5ngRK'},
#   {'artist': 'Glass Animals',
#    'genre': 'pop',
#    'song_name': 'Tangerine',
#    'release_year': '2020',
#    'id_song': '40rOlDoGejXXF4B0BYsjx8'},
#   {'artist': 'Keith Urban',
#    'genre': 'pop',
#    'song_name': 'One Too Many',
#    'release_year': '2020',
#    'id_song': '3X7H1FAiWAW937WvsFeMhe'},
#   {'artist': 'All Time Low',
#    'genre': 'pop',
#    'song_name': 'Monsters (feat. Demi Lovato and blackbear)',
#    'release_year': '2020',
#    'id_song': '50DMJJpAeQv4fIpxZvQz2e'},
#   {'artist': 'YUNGBLUD',
#    'genre': 'pop',
#    'song_name': "god save me, but don't drown me out",
#    'release_year': '2020',
#    'id_song': '0iVSLUaLzYPi1vDFTkjZhb'},
#   {'artist': 'Ariana Grande',
#    'genre': 'pop',
#    'song_name': 'nasty',
#    'release_year': '2020',
#    'id_song': '0sci7ppTZFm4mjcH3nu8yO'},
#   {'artist': 'Glass Animals',
#    'genre': 'pop',
#    'song_name': 'Your Love (Déjà Vu)',
#    'release_year': '2020',
#    'id_song': '0bx6v84HtmEYFRBAOvDTgk'},
#   {'artist': 'Tiwa Savage',
#    'genre': 'pop',
#    'song_name': 'Koroba',
#    'release_year': '2020',
#    'id_song': '18t2ofQiViidZHxOBVjpD1'},
#   {'artist': 'Joji',
#    'genre': 'pop',
#    'song_name': 'Gimme Love',
#    'release_year': '2020',
#    'id_song': '0eF8TYM3rYzdS26URcs4U6'},
#   {'artist': 'BTS',
#    'genre': 'pop',
#    'song_name': 'ON',
#    'release_year': '2020',
#    'id_song': '0fZRNhPJ4AGmwY7rkpdbqK'},
#   {'artist': 'Lee Brice',
#    'genre': 'pop',
#    'song_name': 'One Of Them Girls',
#    'release_year': '2020',
#    'id_song': '14GwnOeC9qYEKEA6uOZepa'},
#   {'artist': 'Agust D',
#    'genre': 'pop',
#    'song_name': 'Daechwita',
#    'release_year': '2020',
#    'id_song': '0JKGe340YJwfDrpXqPQ8sw'},
#   {'artist': 'Ellie Goulding',
#    'genre': 'pop',
#    'song_name': 'Close To Me',
#    'release_year': '2020',
#    'id_song': '2GjMaJ7DacMIkgoe8oMXGg'},
#   {'artist': 'Stray Kids',
#    'genre': 'pop',
#    'song_name': 'District 9',
#    'release_year': '2020',
#    'id_song': '430IfeGHWJxnZOkhBYACt9'},
#   {'artist': 'K/DA',
#    'genre': 'pop',
#    'song_name': 'MORE',
#    'release_year': '2020',
#    'id_song': '6juLaduD4STCUDWT0AYun4'},
#   {'artist': 'Nea',
#    'genre': 'pop',
#    'song_name': 'Some Say - Felix Jaehn Remix',
#    'release_year': '2020',
#    'id_song': '7C1trmcQQ5n5RNy4l6ziCv'},
#   {'artist': 'Wizkid',
#    'genre': 'pop',
#    'song_name': 'True Love (feat. Tay Iwar & Projexx)',
#    'release_year': '2020',
#    'id_song': '4204hwPYuToiuSunPFUoML'},
#   {'artist': 'Ariana Grande',
#    'genre': 'pop',
#    'song_name': 'just like magic',
#    'release_year': '2020',
#    'id_song': '7Dx9Z6Aon1qPS2N0rHSWTe'},
#   {'artist': 'Catching Flies',
#    'genre': 'pop',
#    'song_name': 'Satisfied (Ambient Reprise)',
#    'release_year': '2020',
#    'id_song': '2k5SEAK05D29ZkqbnFgIVL'},
#   {'artist': 'Zara Larsson',
#    'genre': 'pop',
#    'song_name': 'WOW (feat. Sabrina Carpenter) - Remix',
#    'release_year': '2020',
#    'id_song': '5WokFKscrfGEGGLPTu3jgO'},
#   {'artist': 'Sam Smith',
#    'genre': 'pop',
#    'song_name': 'Diamonds',
#    'release_year': '2020',
#    'id_song': '1hJIbOjWpid6LtnozHmzRS'},
#   {'artist': 'BTS',
#    'genre': 'pop',
#    'song_name': 'Black Swan',
#    'release_year': '2020',
#    'id_song': '2EmcTFQ1rM11wp2ztsXTHa'},
#   {'artist': 'SPINALL',
#    'genre': 'pop',
#    'song_name': 'Sere',
#    'release_year': '2020',
#    'id_song': '35056uy2b4M1qJ3Z1ed3sf'},
#   {'artist': 'Wallows',
#    'genre': 'pop',
#    'song_name': 'OK',
#    'release_year': '2020',
#    'id_song': '0APAKxMXB7jdDs4kw1l30y'},
#   {'artist': 'Theophilus London',
#    'genre': 'pop',
#    'song_name': 'Only You',
#    'release_year': '2020',
#    'id_song': '2rDwETmcGw4ZqbuXvLQmDL'},
#   {'artist': 'Frances Forever',
#    'genre': 'pop',
#    'song_name': 'space girl',
#    'release_year': '2020',
#    'id_song': '7FjIYiD53wxlQmzTT6Wdpf'},
#   {'artist': 'mgk',
#    'genre': 'pop',
#    'song_name': 'kiss kiss',
#    'release_year': '2020',
#    'id_song': '69LvvkHnFFnX3d5eNObtMo'},
#   {'artist': 'Teddy Swims',
#    'genre': 'pop',
#    'song_name': 'Broke (feat. Thomas Rhett)',
#    'release_year': '2020',
#    'id_song': '1etcoCl2mkHpMHkMVco8iz'},
#   {'artist': 'Charli xcx',
#    'genre': 'pop',
#    'song_name': 'anthems',
#    'release_year': '2020',
#    'id_song': '2ljvO8ZpKFMT3HXwCjW4Yw'},
#   {'artist': 'Lady Gaga',
#    'genre': 'pop',
#    'song_name': 'Sour Candy (with BLACKPINK)',
#    'release_year': '2020',
#    'id_song': '1IWNylpZ477gIVUDpJL66u'},
#   {'artist': 'Miley Cyrus',
#    'genre': 'pop',
#    'song_name': 'Plastic Hearts',
#    'release_year': '2020',
#    'id_song': '6qCsKKS7Ol63SJW3LOIX5R'},
#   {'artist': 'Stray Kids',
#    'genre': 'pop',
#    'song_name': 'My Pace',
#    'release_year': '2020',
#    'id_song': '4yJUQqcnYkDafFzguSbZAl'},
#   {'artist': 'ITZY',
#    'genre': 'pop',
#    'song_name': 'WANNABE',
#    'release_year': '2020',
#    'id_song': '4pspYVQGFHLPEFgQPD1J7e'},
#   {'artist': 'Yung Gravy',
#    'genre': 'pop',
#    'song_name': 'oops!',
#    'release_year': '2020',
#    'id_song': '7L6G0wpIUiPXuvoo7qhb06'},
#   {'artist': 'Olivia Rodrigo',
#    'genre': 'pop',
#    'song_name': 'good 4 u',
#    'release_year': '2021',
#    'id_song': '4ZtFanR9U6ndgddUvNcjcG'},
#   {'artist': 'Olivia Rodrigo',
#    'genre': 'pop',
#    'song_name': 'deja vu',
#    'release_year': '2021',
#    'id_song': '6HU7h9RYOaPRFeh0R3UeAr'},
#   {'artist': 'Doja Cat',
#    'genre': 'pop',
#    'song_name': 'Kiss Me More (feat. SZA)',
#    'release_year': '2021',
#    'id_song': '3DarAbFujv6eYNliUTyqtz'},
#   {'artist': 'Olivia Rodrigo',
#    'genre': 'pop',
#    'song_name': 'jealousy, jealousy',
#    'release_year': '2021',
#    'id_song': '0MMyJUC3WNnFS1lit5pTjk'},
#   {'artist': 'Cafuné',
#    'genre': 'pop',
#    'song_name': 'Tek It',
#    'release_year': '2021',
#    'id_song': '751srcHf5tUqcEa9pRCQwP'},
#   {'artist': 'Adele',
#    'genre': 'pop',
#    'song_name': 'Easy On Me',
#    'release_year': '2021',
#    'id_song': '46IZ0fSY2mpAiktS3KOqds'},
#   {'artist': 'Taylor Swift',
#    'genre': 'pop',
#    'song_name': 'You Belong With Me (Taylor’s Version)',
#    'release_year': '2021',
#    'id_song': '1qrpoAMXodY6895hGKoUpA'},
#   {'artist': 'Elton John',
#    'genre': 'pop',
#    'song_name': 'Cold Heart - PNAU Remix',
#    'release_year': '2021',
#    'id_song': '6JIC3hbC28JZKZ8AlAqX8h'},
#   {'artist': 'Gracie Abrams',
#    'genre': 'pop',
#    'song_name': 'Mess It Up',
#    'release_year': '2021',
#    'id_song': '0PLhwCmQ7cC3ThRGPn3HxF'},
#   {'artist': 'Elton John',
#    'genre': 'pop',
#    'song_name': 'Cold Heart - PNAU Remix',
#    'release_year': '2021',
#    'id_song': '6zSpb8dQRaw0M1dK8PBwQz'},
#   {'artist': 'PinkPantheress',
#    'genre': 'pop',
#    'song_name': 'I Must Apologise',
#    'release_year': '2021',
#    'id_song': '2rrq3SGYxk90xLx5fMmPhZ'},
#   {'artist': 'Olivia Rodrigo',
#    'genre': 'pop',
#    'song_name': 'brutal',
#    'release_year': '2021',
#    'id_song': '6SRsiMl7w1USE4mFqrOhHC'},
#   {'artist': 'Eyedress',
#    'genre': 'pop',
#    'song_name': 'Something About You',
#    'release_year': '2021',
#    'id_song': '6RiiSy9GzSwiyDEJDiMuKe'},
#   {'artist': 'Billie Eilish',
#    'genre': 'pop',
#    'song_name': 'NDA',
#    'release_year': '2021',
#    'id_song': '38GBNKZUhfBkk3oNlWzRYd'},
#   {'artist': 'Lost Frequencies',
#    'genre': 'pop',
#    'song_name': 'Where Are You Now',
#    'release_year': '2021',
#    'id_song': '3uUuGVFu1V7jTQL60S1r8z'},
#   {'artist': 'Doja Cat',
#    'genre': 'pop',
#    'song_name': 'Woman',
#    'release_year': '2021',
#    'id_song': '6Uj1ctrBOjOas8xZXGqKk4'},
#   {'artist': 'Olivia Rodrigo',
#    'genre': 'pop',
#    'song_name': 'enough for you',
#    'release_year': '2021',
#    'id_song': '2TOzTqQXNmR2zDJXihjZ2e'},
#   {'artist': 'Majestic',
#    'genre': 'pop',
#    'song_name': 'Rasputin',
#    'release_year': '2021',
#    'id_song': '0b18g3G5spr4ZCkz7Y6Q0Q'},
#   {'artist': 'Adele',
#    'genre': 'pop',
#    'song_name': 'I Drink Wine',
#    'release_year': '2021',
#    'id_song': '6v0UJD4a2FtleHeSYVX02A'},
#   {'artist': 'Riton',
#    'genre': 'pop',
#    'song_name': 'Friday (feat. Mufasa & Hypeman) - Dopamine Re-Edit',
#    'release_year': '2021',
#    'id_song': '4cG7HUWYHBV6R6tHn1gxrl'},
#   {'artist': 'Adele',
#    'genre': 'pop',
#    'song_name': 'Easy On Me',
#    'release_year': '2021',
#    'id_song': '0gplL1WMoJ6iYaPgMCL0gX'},
#   {'artist': 'Duran Duran',
#    'genre': 'pop',
#    'song_name': 'INVISIBLE',
#    'release_year': '2021',
#    'id_song': '51EpFns3CG9taCMQz6XDom'},
#   {'artist': 'The Weeknd',
#    'genre': 'pop',
#    'song_name': 'Save Your Tears (with Ariana Grande) (Remix)',
#    'release_year': '2021',
#    'id_song': '37BZB0z9T8Xu7U3e65qxFy'},
#   {'artist': 'Taylor Swift',
#    'genre': 'pop',
#    'song_name': "Red (Taylor's Version)",
#    'release_year': '2021',
#    'id_song': '4OAuvHryIVv4kMDNSLuPt6'},
#   {'artist': 'Joel Corry',
#    'genre': 'pop',
#    'song_name': 'BED',
#    'release_year': '2021',
#    'id_song': '0siYMEsGrzzzlWLXK5zJfS'},
#   {'artist': 'bbno$',
#    'genre': 'pop',
#    'song_name': 'edamame',
#    'release_year': '2021',
#    'id_song': '1golLrmqyxDWedF7YUHCOD'},
#   {'artist': 'Joel Corry',
#    'genre': 'pop',
#    'song_name': 'OUT OUT (feat. Charli XCX & Saweetie)',
#    'release_year': '2021',
#    'id_song': '6Dy1jexKYriXAVG6evyUTJ'},
#   {'artist': 'Marshmello',
#    'genre': 'pop',
#    'song_name': 'Leave Before You Love Me (with Jonas Brothers)',
#    'release_year': '2021',
#    'id_song': '4qu63nuBpdn0qHUHuObEj1'},
#   {'artist': 'Billie Eilish',
#    'genre': 'pop',
#    'song_name': 'Therefore I Am',
#    'release_year': '2021',
#    'id_song': '20R4HfKloPKgXDqU7UKk3x'},
#   {'artist': 'Coldplay',
#    'genre': 'pop',
#    'song_name': 'My Universe',
#    'release_year': '2021',
#    'id_song': '46HNZY1i7O6jwTA7Slo2PI'},
#   {'artist': 'Doja Cat',
#    'genre': 'pop',
#    'song_name': 'Need to Know',
#    'release_year': '2021',
#    'id_song': '3Vi5XqYrmQgOYBajMWSvCi'},
#   {'artist': 'Gracie Abrams',
#    'genre': 'pop',
#    'song_name': 'Feels Like',
#    'release_year': '2021',
#    'id_song': '35IcAVSMsU9qzHfpPbvC8A'},
#   {'artist': 'Jungle',
#    'genre': 'pop',
#    'song_name': 'Keep Moving',
#    'release_year': '2021',
#    'id_song': '4rf0IVQDFjr27T4sgah5Pf'},
#   {'artist': 'LEISURE',
#    'genre': 'pop',
#    'song_name': 'Slipping Away',
#    'release_year': '2021',
#    'id_song': '07AbRgKmb5KfppwtZbZqDI'},
#   {'artist': 'Billie Eilish',
#    'genre': 'pop',
#    'song_name': 'Oxytocin',
#    'release_year': '2021',
#    'id_song': '4t2OeILB07eMGTXSUbMPEu'},
#   {'artist': 'EKKSTACY',
#    'genre': 'pop',
#    'song_name': 'i walk this earth all by myself',
#    'release_year': '2021',
#    'id_song': '6oofvZ4K8vBHnCT1oKERcd'},
#   {'artist': 'OneRepublic',
#    'genre': 'pop',
#    'song_name': 'Run',
#    'release_year': '2021',
#    'id_song': '6KL88T4Ma4ABXqzgUoEwkd'},
#   {'artist': 'Clairo',
#    'genre': 'pop',
#    'song_name': 'Amoeba',
#    'release_year': '2021',
#    'id_song': '0HAqq2GcQKyi3s87GuN7jU'},
#   {'artist': 'Taylor Swift',
#    'genre': 'pop',
#    'song_name': 'Fearless (Taylor’s Version)',
#    'release_year': '2021',
#    'id_song': '77sMIMlNaSURUAXq5coCxE'},
#   {'artist': 'Taylor Swift',
#    'genre': 'pop',
#    'song_name': "We Are Never Ever Getting Back Together (Taylor's Version)",
#    'release_year': '2021',
#    'id_song': '5YqltLsjdqFtvqE7Nrysvs'},
#   {'artist': 'Lil Nas X',
#    'genre': 'pop',
#    'song_name': 'THATS WHAT I WANT',
#    'release_year': '2021',
#    'id_song': '0e8nrvls4Qqv5Rfa2UhqmO'},
#   {'artist': 'Coldplay',
#    'genre': 'pop',
#    'song_name': 'My Universe',
#    'release_year': '2021',
#    'id_song': '3FeVmId7tL5YN8B7R3imoM'},
#   {'artist': 'Taylor Swift',
#    'genre': 'pop',
#    'song_name': 'The Way I Loved You (Taylor’s Version)',
#    'release_year': '2021',
#    'id_song': '22bPsP2jCgbLUvh82U0Z3M'},
#   {'artist': 'Olivia Dean',
#    'genre': 'pop',
#    'song_name': 'Be My Own Boyfriend',
#    'release_year': '2021',
#    'id_song': '0DXZHcAQAkXx8YlMIdzqgG'},
#   {'artist': 'Galantis',
#    'genre': 'pop',
#    'song_name': 'Heartbreak Anthem (with David Guetta & Little Mix)',
#    'release_year': '2021',
#    'id_song': '5K6Ssv4Z3zRvxt0P6EKUAP'},
#   {'artist': 'Ashe',
#    'genre': 'pop',
#    'song_name': 'Till Forever Falls Apart',
#    'release_year': '2021',
#    'id_song': '4x5YzxjrF9wvIIXJV7TveC'},
#   {'artist': 'Taylor Swift',
#    'genre': 'pop',
#    'song_name': "22 (Taylor's Version)",
#    'release_year': '2021',
#    'id_song': '3yII7UwgLF6K5zW3xad3MP'},
#   {'artist': 'ENHYPEN',
#    'genre': 'pop',
#    'song_name': 'Drunk-Dazed',
#    'release_year': '2021',
#    'id_song': '1wcr8DjnN59Awev8nnKpQ4'},
#   {'artist': 'Taylor Swift',
#    'genre': 'pop',
#    'song_name': "Wildest Dreams (Taylor's Version)",
#    'release_year': '2021',
#    'id_song': '1Ov37jtRQ2YNAe8HzfczkL'},
#   {'artist': 'Adele',
#    'genre': 'pop',
#    'song_name': 'Oh My God',
#    'release_year': '2021',
#    'id_song': '3Kkjo3cT83cw09VJyrLNwX'},
#   {'artist': 'Doja Cat',
#    'genre': 'pop',
#    'song_name': 'You Right',
#    'release_year': '2021',
#    'id_song': '0k4d5YPDr1r7FX77VdqWez'},
#   {'artist': 'Billie Eilish',
#    'genre': 'pop',
#    'song_name': 'my future',
#    'release_year': '2021',
#    'id_song': '3YUMWmx8EJq0DurfuIwoGh'},
#   {'artist': 'Taylor Swift',
#    'genre': 'pop',
#    'song_name': "I Knew You Were Trouble (Taylor's Version)",
#    'release_year': '2021',
#    'id_song': '6AtZLIzUINvExIUy4QhdjP'},
#   {'artist': 'Billie Eilish',
#    'genre': 'pop',
#    'song_name': 'Lost Cause',
#    'release_year': '2021',
#    'id_song': '4191RXFPa7Ge9XkA4cWlna'},
#   {'artist': 'JP Saxe',
#    'genre': 'pop',
#    'song_name': 'If the World Was Ending (feat. Julia Michaels)',
#    'release_year': '2021',
#    'id_song': '4bp5G6x1SXMQW4X9DbCCCp'},
#   {'artist': 'Fireboy DML',
#    'genre': 'pop',
#    'song_name': 'Peru',
#    'release_year': '2021',
#    'id_song': '4hJhHbkhZFnxmWbAkZRoe0'},
#   {'artist': 'Olivia Dean',
#    'genre': 'pop',
#    'song_name': 'Float',
#    'release_year': '2021',
#    'id_song': '031T6v4JIcPlkbzOrpzOnv'},
#   {'artist': 'Lana Del Rey',
#    'genre': 'pop',
#    'song_name': 'Living Legend',
#    'release_year': '2021',
#    'id_song': '6pZ9Nj3vzj1RW4ZkR9GcQ9'},
#   {'artist': 'Maroon 5',
#    'genre': 'pop',
#    'song_name': 'Beautiful Mistakes (feat. Megan Thee Stallion)',
#    'release_year': '2021',
#    'id_song': '5zFglKYiknIxks8geR8rcL'},
#   {'artist': 'Olivia Dean',
#    'genre': 'pop',
#    'song_name': 'Cross My Mind',
#    'release_year': '2021',
#    'id_song': '6TKMXuPoDlPZYEkpS5CMB7'},
#   {'artist': 'Elton John',
#    'genre': 'pop',
#    'song_name': 'Hold Me Closer',
#    'release_year': '2021',
#    'id_song': '5TJEBoTCDbJXiKMdCN9pd3'},
#   {'artist': 'Japanese Breakfast',
#    'genre': 'pop',
#    'song_name': 'Be Sweet',
#    'release_year': '2021',
#    'id_song': '0dpyzcT3RMNNSd2xKBf35I'},
#   {'artist': 'Becky Hill',
#    'genre': 'pop',
#    'song_name': 'Last Time - Acoustic',
#    'release_year': '2021',
#    'id_song': '54u4wxyfvWnAIdSs0HIvsm'},
#   {'artist': 'Joy Crookes',
#    'genre': 'pop',
#    'song_name': 'When You Were Mine',
#    'release_year': '2021',
#    'id_song': '3zSwFE91EdwhEwS6vnJohB'},
#   {'artist': 'Durand Jones & The Indications',
#    'genre': 'pop',
#    'song_name': 'Witchoo',
#    'release_year': '2021',
#    'id_song': '6W9rbkBueZQrwuzO24GHZ2'},
#   {'artist': 'Tiësto',
#    'genre': 'pop',
#    'song_name': 'The Motto',
#    'release_year': '2021',
#    'id_song': '18asYwWugKjjsihZ0YvRxO'},
#   {'artist': 'beabadoobee',
#    'genre': 'pop',
#    'song_name': 'Cologne',
#    'release_year': '2021',
#    'id_song': '1NaDK3atogQEn9glK5fYuy'},
#   {'artist': 'NEIKED',
#    'genre': 'pop',
#    'song_name': 'Better Days (NEIKED x Mae Muller x Polo G)',
#    'release_year': '2021',
#    'id_song': '6f5ExP43esnvdKPddwKXJH'},
#   {'artist': 'Billie Eilish',
#    'genre': 'pop',
#    'song_name': 'Not My Responsibility',
#    'release_year': '2021',
#    'id_song': '4T2zre0jqstNJ5Gt0WG9lz'},
#   {'artist': 'Ed Sheeran',
#    'genre': 'pop',
#    'song_name': 'Overpass Graffiti',
#    'release_year': '2021',
#    'id_song': '4btFHqumCO31GksfuBLLv3'},
#   {'artist': 'Calvin Harris',
#    'genre': 'pop',
#    'song_name': 'By Your Side (feat. Tom Grennan)',
#    'release_year': '2021',
#    'id_song': '0vR2rIVORmgeKiGIgNT0fV'},
#   {'artist': 'ENHYPEN',
#    'genre': 'pop',
#    'song_name': 'FEVER',
#    'release_year': '2021',
#    'id_song': '0UzymivvUH5s8z4PeWZJaK'},
#   {'artist': 'Billie Eilish',
#    'genre': 'pop',
#    'song_name': 'GOLDWING',
#    'release_year': '2021',
#    'id_song': '0FfqyjhB6Kspvit1oOo7ax'},
#   {'artist': 'Regard',
#    'genre': 'pop',
#    'song_name': 'You',
#    'release_year': '2021',
#    'id_song': '2cc8Sw1OnCuA5bV8nqWqpE'},
#   {'artist': 'Zara Larsson',
#    'genre': 'pop',
#    'song_name': 'Ruin My Life',
#    'release_year': '2021',
#    'id_song': '4nyY8oVjbX2d4qzlpiVM5n'},
#   {'artist': "Rag'n'Bone Man",
#    'genre': 'pop',
#    'song_name': 'Anywhere Away from Here (Rag’n’Bone Man & P!nk)',
#    'release_year': '2021',
#    'id_song': '5gjATWO1EIhrCP1CQ2GWg8'},
#   {'artist': 'Stray Kids',
#    'genre': 'pop',
#    'song_name': 'Thunderous',
#    'release_year': '2021',
#    'id_song': '0nwTMzpatarzvLvtwwzdCt'},
#   {'artist': 'Taylor Swift',
#    'genre': 'pop',
#    'song_name': 'Mr. Perfectly Fine (Taylor’s Version) (From The Vault)',
#    'release_year': '2021',
#    'id_song': '2CYVETnhM9aytqrazYYwrK'},
#   {'artist': 'LISA',
#    'genre': 'pop',
#    'song_name': 'MONEY',
#    'release_year': '2021',
#    'id_song': '7hU3IHwjX150XLoTVmjD0q'},
#   {'artist': 'Doja Cat',
#    'genre': 'pop',
#    'song_name': 'Been Like This',
#    'release_year': '2021',
#    'id_song': '7y3xU9vEC1s8DSuuoSYKih'},
#   {'artist': 'Billie Eilish',
#    'genre': 'pop',
#    'song_name': 'OverHeated',
#    'release_year': '2021',
#    'id_song': '5uSG6fUPRaehaV820zcpsK'},
#   {'artist': 'Stray Kids',
#    'genre': 'pop',
#    'song_name': 'Red Lights (Bang Chan, Hyunjin)',
#    'release_year': '2021',
#    'id_song': '0LatE4S9UtCDwIdGQsFFKL'},
#   {'artist': 'Remi Wolf',
#    'genre': 'pop',
#    'song_name': 'Photo ID (with Dominic Fike)',
#    'release_year': '2021',
#    'id_song': '1F35Dmog9pekyCVnH1eQpl'},
#   {'artist': 'Taylor Swift',
#    'genre': 'pop',
#    'song_name': "Message In A Bottle (Taylor's Version) (From The Vault)",
#    'release_year': '2021',
#    'id_song': '3z6XUommYDWPHeFhmhhT6j'},
#   {'artist': 'P!nk',
#    'genre': 'pop',
#    'song_name': 'Cover Me In Sunshine',
#    'release_year': '2021',
#    'id_song': '6Tio0ZoDeSQnI7EBAqWer2'},
#   {'artist': 'Mimi Webb',
#    'genre': 'pop',
#    'song_name': 'Good Without',
#    'release_year': '2021',
#    'id_song': '0xqHkO5570zlGpLpCnd4MG'},
#   {'artist': 'Purple Disco Machine',
#    'genre': 'pop',
#    'song_name': 'Hypnotized',
#    'release_year': '2021',
#    'id_song': '7HxWZggiHyGWT9ZSmWzcxu'},
#   {'artist': 'Taylor Swift',
#    'genre': 'pop',
#    'song_name': "The Very First Night (Taylor's Version) (From The Vault)",
#    'release_year': '2021',
#    'id_song': '6pYNq0ZwpPVazKzsqpf0G8'},
#   {'artist': 'David Guetta',
#    'genre': 'pop',
#    'song_name': 'If You Really Love Me (How Will I Know)',
#    'release_year': '2021',
#    'id_song': '5TnF44IQRsopRNa63BEyFd'},
#   {'artist': 'Tate McRae',
#    'genre': 'pop',
#    'song_name': 'rubberband',
#    'release_year': '2021',
#    'id_song': '2E8IlL26PwtZq7CqAHBBUw'},
#   {'artist': 'OneRepublic',
#    'genre': 'pop',
#    'song_name': 'Rescue Me',
#    'release_year': '2021',
#    'id_song': '37LNNQNbL1YLyutBG6aWRx'},
#   {'artist': 'TWICE',
#    'genre': 'pop',
#    'song_name': 'The Feels',
#    'release_year': '2021',
#    'id_song': '308Ir17KlNdlrbVLHWhlLe'},
#   {'artist': 'Twenty One Pilots',
#    'genre': 'pop',
#    'song_name': 'Shy Away',
#    'release_year': '2021',
#    'id_song': '2nG54Y4a3sH9YpfxMolOyi'},
#   {'artist': 'AP Dhillon',
#    'genre': 'pop',
#    'song_name': 'Insane',
#    'release_year': '2021',
#    'id_song': '3UhmuWcFaLS3AO3kI9ynQ2'},
#   {'artist': 'Bruno Mars',
#    'genre': 'pop',
#    'song_name': 'Skate',
#    'release_year': '2021',
#    'id_song': '7jvCeWOSnJs2N3spqobWnO'},
#   {'artist': 'Stray Kids',
#    'genre': 'pop',
#    'song_name': 'DOMINO',
#    'release_year': '2021',
#    'id_song': '6Ib6RkvLBMD85bov85apSL'},
#   {'artist': 'Clean Bandit',
#    'genre': 'pop',
#    'song_name': 'Drive (feat. Wes Nelson)',
#    'release_year': '2021',
#    'id_song': '6eCmK3GQyFuTNWCJHsaF9d'},
#   {'artist': 'New Constellations',
#    'genre': 'pop',
#    'song_name': 'Hot Blooded',
#    'release_year': '2021',
#    'id_song': '1ElySIlHwm1HX7sUjAZZnp'},
#   {'artist': 'Ed Sheeran',
#    'genre': 'pop',
#    'song_name': '2step',
#    'release_year': '2021',
#    'id_song': '2SUxn2O9NHL6GHGQFgwCY0'},
#   {'artist': 'Dua Lipa',
#    'genre': 'pop',
#    'song_name': "We're Good",
#    'release_year': '2021',
#    'id_song': '1diS6nkxMQc3wwC4G1j0bh'},
#   {'artist': 'Dua Lipa',
#    'genre': 'pop',
#    'song_name': "We're Good",
#    'release_year': '2021',
#    'id_song': '1diS6nkxMQc3wwC4G1j0bh'},
#   {'artist': 'Jasleen Royal',
#    'genre': 'pop',
#    'song_name': 'Ranjha (From "Shershaah")',
#    'release_year': '2021',
#    'id_song': '72zHuDxFQTjbL51qJQSA7j'},
#   {'artist': 'Dayglow',
#    'genre': 'pop',
#    'song_name': 'Close To You',
#    'release_year': '2021',
#    'id_song': '50PyquzZ9BaBwLZZd1AuuV'},
#   {'artist': 'late night drive home',
#    'genre': 'pop',
#    'song_name': 'Stress Relief',
#    'release_year': '2021',
#    'id_song': '7xLfmCx9jcZNgzlIK7NupN'},
#   {'artist': 'OneRepublic',
#    'genre': 'pop',
#    'song_name': 'Run',
#    'release_year': '2021',
#    'id_song': '2UbVnbE5FH6008mAm6Mmgw'},
#   {'artist': 'P!nk',
#    'genre': 'pop',
#    'song_name': 'Cover Me In Sunshine',
#    'release_year': '2021',
#    'id_song': '0UKUfxIkDAMZz7hMdiVX3m'},
#   {'artist': 'Whitney Houston',
#    'genre': 'pop',
#    'song_name': 'How Will I Know',
#    'release_year': '2021',
#    'id_song': '79wbJeLkXOlJh4AzaWCWfL'},
#   {'artist': 'Teddy Swims',
#    'genre': 'pop',
#    'song_name': 'Simple Things',
#    'release_year': '2021',
#    'id_song': '3qTnncgYlMT0k0Z0prgUgD'},
#   {'artist': 'Thomas Rhett',
#    'genre': 'pop',
#    'song_name': 'What’s Your Country Song',
#    'release_year': '2021',
#    'id_song': '4oR2cCQGs0Yt0Mgr2diV6V'},
#   {'artist': 'Sabrina Carpenter',
#    'genre': 'pop',
#    'song_name': 'Skin',
#    'release_year': '2021',
#    'id_song': '03B2SfXuvDh1m9F4tqrX07'},
#   {'artist': 'Benson Boone',
#    'genre': 'pop',
#    'song_name': 'Ghost Town',
#    'release_year': '2021',
#    'id_song': '135Lf4Q0CzlMNfOxbEUsLH'},
#   {'artist': 'Taylor Swift',
#    'genre': 'pop',
#    'song_name': 'Mr. Perfectly Fine (Taylor’s Version) (From The Vault)',
#    'release_year': '2021',
#    'id_song': '7l2tmgUhV7Y2aJHjiszifg'},
#   {'artist': 'LPB Poody',
#    'genre': 'pop',
#    'song_name': 'Batman',
#    'release_year': '2021',
#    'id_song': '1xMvdOFQaql3EBkHmuh2TK'},
#   {'artist': 'Joel Corry',
#    'genre': 'pop',
#    'song_name': 'I Wish (feat. Mabel)',
#    'release_year': '2021',
#    'id_song': '0YORgvqP1MotwCnDZzOwII'},
#   {'artist': "Rag'n'Bone Man",
#    'genre': 'pop',
#    'song_name': 'All You Ever Wanted',
#    'release_year': '2021',
#    'id_song': '7nX1m12HTyIyiATwrcHCUh'},
#   {'artist': 'girl in red',
#    'genre': 'pop',
#    'song_name': 'midnight love',
#    'release_year': '2021',
#    'id_song': '32XaqPVTVkkuOiOPQZ3SpA'},
#   {'artist': 'Olivia Rodrigo',
#    'genre': 'pop',
#    'song_name': 'good 4 u',
#    'release_year': '2021',
#    'id_song': '6P4d1NWBCNIYZjzF9k1mVN'},
#   {'artist': 'ROSÉ',
#    'genre': 'pop',
#    'song_name': 'On The Ground',
#    'release_year': '2021',
#    'id_song': '2pn8dNVSpYnAtlKFC8Q0DJ'},
#   {'artist': 'Adele',
#    'genre': 'pop',
#    'song_name': 'Can I Get It',
#    'release_year': '2021',
#    'id_song': '6w8ZPYdnGajyfPddTWdthN'},
#   {'artist': 'Adele',
#    'genre': 'pop',
#    'song_name': 'My Little Love',
#    'release_year': '2021',
#    'id_song': '2DuPBbS5mIldXnh7Wum8Cy'},
#   {'artist': 'Nessa Barrett',
#    'genre': 'pop',
#    'song_name': 'la di die (feat. Jaden Hossler)',
#    'release_year': '2021',
#    'id_song': '3RLshk3cDQOqWhSIRCVaXL'},
#   {'artist': 'Ashe',
#    'genre': 'pop',
#    'song_name': 'Till Forever Falls Apart',
#    'release_year': '2021',
#    'id_song': '2769RhOZs0ezRncRW1vryp'},
#   {'artist': 'Anne-Marie',
#    'genre': 'pop',
#    'song_name': 'Kiss My (Uh Oh)',
#    'release_year': '2021',
#    'id_song': '0MWiSBKm8Avs8iDIxcertp'},
#   {'artist': 'Taylor Swift',
#    'genre': 'pop',
#    'song_name': "22 (Taylor's Version)",
#    'release_year': '2021',
#    'id_song': '2T9WeqSMJJb8YBDHPYGU4p'},
#   {'artist': 'Ayra Starr',
#    'genre': 'pop',
#    'song_name': 'Bloody Samaritan',
#    'release_year': '2021',
#    'id_song': '1OoPhcM78evXIxjmSzCnmf'},
#   {'artist': 'Wizkid',
#    'genre': 'pop',
#    'song_name': 'Mood (feat. BNXN)',
#    'release_year': '2021',
#    'id_song': '6jdTkoEaer7XNGSblczoSu'},
#   {'artist': 'Simple Plan',
#    'genre': 'pop',
#    'song_name': "What's New Scooby-Doo?",
#    'release_year': '2021',
#    'id_song': '6DD5beNG6Ji3AYp5WrYnwD'},
#   {'artist': 'Jason Derulo',
#    'genre': 'pop',
#    'song_name': 'Acapulco',
#    'release_year': '2021',
#    'id_song': '3eJH2nAjvNXdmPfBkALiPZ'},
#   {'artist': 'Yebba',
#    'genre': 'pop',
#    'song_name': 'Far Away (feat. A$AP Rocky)',
#    'release_year': '2021',
#    'id_song': '14qNHvX8h6HoynFuV0RxWS'},
#   {'artist': 'Tom Grennan',
#    'genre': 'pop',
#    'song_name': "Don't Break the Heart",
#    'release_year': '2021',
#    'id_song': '4tS2pyUXiaTjHK7vCBomyF'},
#   {'artist': 'Alesso',
#    'genre': 'pop',
#    'song_name': 'When I’m Gone (with Katy Perry)',
#    'release_year': '2021',
#    'id_song': '5902W4uHWzhtOff1UK7the'},
#   {'artist': 'LISA',
#    'genre': 'pop',
#    'song_name': 'LALISA',
#    'release_year': '2021',
#    'id_song': '7uQZVznj0uQOGC9KhV2Mg6'},
#   {'artist': 'Mimi Webb',
#    'genre': 'pop',
#    'song_name': 'Good Without',
#    'release_year': '2021',
#    'id_song': '15OCqNPYoLziEAsbVnqRj5'},
#   {'artist': 'The Marías',
#    'genre': 'pop',
#    'song_name': 'Hush',
#    'release_year': '2021',
#    'id_song': '4zXZ5Mq2L6jnsOsTssgRh8'},
#   {'artist': 'Rema',
#    'genre': 'pop',
#    'song_name': 'Soundgasm',
#    'release_year': '2021',
#    'id_song': '5c549LWiKCWGvcDsZwMN6v'},
#   {'artist': 'Lorde',
#    'genre': 'pop',
#    'song_name': 'The Path',
#    'release_year': '2021',
#    'id_song': '7JqqIi2ktnsNkYdQhKSCrz'},
#   {'artist': 'Hotel Ugly',
#    'genre': 'pop',
#    'song_name': "Stevie Doesn't Wonder",
#    'release_year': '2021',
#    'id_song': '7BgyWwbbybJr2IbQoI1gzH'},
#   {'artist': 'Post Malone',
#    'genre': 'pop',
#    'song_name': 'One Right Now (with The Weeknd)',
#    'release_year': '2021',
#    'id_song': '00Blm7zeNqgYLPtW6zg8cj'},
#   {'artist': 'Stellar',
#    'genre': 'pop',
#    'song_name': 'El Dorado',
#    'release_year': '2021',
#    'id_song': '3p94RpSxQdZocUfrzpemmm'},
#   {'artist': 'BTS',
#    'genre': 'pop',
#    'song_name': 'Permission to Dance',
#    'release_year': '2021',
#    'id_song': '3XYRV7ZSHqIRDG87DKTtry'},
#   {'artist': 'MARINA',
#    'genre': 'pop',
#    'song_name': 'Ancient Dreams in a Modern Land',
#    'release_year': '2021',
#    'id_song': '1R1ihosU2CSEaSw8e5ZF6E'},
#   {'artist': 'Billie Eilish',
#    'genre': 'pop',
#    'song_name': 'Oxytocin',
#    'release_year': '2021',
#    'id_song': '0UJAH9v2PmS7sBcuBquprR'},
#   {'artist': 'FAVE',
#    'genre': 'pop',
#    'song_name': 'Baby Riddim',
#    'release_year': '2021',
#    'id_song': '77eZIuMTB9HrQ86L4ljqEX'},
#   {'artist': 'Rema',
#    'genre': 'pop',
#    'song_name': 'Soundgasm',
#    'release_year': '2021',
#    'id_song': '6NcSi0HjkHbnH038uVg8OV'},
#   {'artist': 'Q',
#    'genre': 'pop',
#    'song_name': 'Take Me Where Your Heart Is',
#    'release_year': '2021',
#    'id_song': '1RJl5cZ8kFpoVFOS2x6scI'},
#   {'artist': 'ROSÉ',
#    'genre': 'pop',
#    'song_name': 'Gone',
#    'release_year': '2021',
#    'id_song': '2dHoVW9AxJVSRebPRyV2aA'},
#   {'artist': 'Stray Kids',
#    'genre': 'pop',
#    'song_name': 'CHEESE',
#    'release_year': '2021',
#    'id_song': '7qpSatdWQcRHA3hpedL2u4'},
#   {'artist': 'Ed Sheeran',
#    'genre': 'pop',
#    'song_name': 'Shivers - Ofenbach Remix',
#    'release_year': '2021',
#    'id_song': '1eGlStOBtFJ6Oc4hhN5tUR'},
#   {'artist': 'P!nk',
#    'genre': 'pop',
#    'song_name': 'All I Know So Far',
#    'release_year': '2021',
#    'id_song': '4LmN3eU1R1vVEdKuDELpGk'},
#   {'artist': 'Tate McRae',
#    'genre': 'pop',
#    'song_name': 'slower',
#    'release_year': '2021',
#    'id_song': '4X3Br7EVc8oy44zUwU1z5w'},
#   {'artist': 'Ozzy Osbourne',
#    'genre': 'rock',
#    'song_name': 'Crazy Train',
#    'release_year': '2020',
#    'id_song': '7ACxUo21jtTHzy7ZEV56vU'},
#   {'artist': 'Tame Impala',
#    'genre': 'rock',
#    'song_name': 'Borderline',
#    'release_year': '2020',
#    'id_song': '5hM5arv9KDbCHS0k9uqwjr'},
#   {'artist': 'The Strokes',
#    'genre': 'rock',
#    'song_name': 'The Adults Are Talking',
#    'release_year': '2020',
#    'id_song': '5ruzrDWcT0vuJIOMW7gMnW'},
#   {'artist': 'VOILÀ',
#    'genre': 'rock',
#    'song_name': 'Figure You Out',
#    'release_year': '2020',
#    'id_song': '2bFGGsScXp2Tu10jKMCKO6'},
#   {'artist': 'YUNGBLUD',
#    'genre': 'rock',
#    'song_name': 'parents',
#    'release_year': '2020',
#    'id_song': '5v4OkFH0TJ6W1hCFxyn0px'},
#   {'artist': 'Tame Impala',
#    'genre': 'rock',
#    'song_name': 'Is It True',
#    'release_year': '2020',
#    'id_song': '6RZmhpvukfyeSURhf4kZ0d'},
#   {'artist': 'mgk',
#    'genre': 'rock',
#    'song_name': "my ex's best friend (with blackbear)",
#    'release_year': '2020',
#    'id_song': '7kDUspsoYfLkWnZR7qwHZl'},
#   {'artist': 'The Strokes',
#    'genre': 'rock',
#    'song_name': 'Selfless',
#    'release_year': '2020',
#    'id_song': '2t0wwvR15fc3K1ey8OiOaN'},
#   {'artist': 'The Black Keys',
#    'genre': 'rock',
#    'song_name': "Howlin' for You",
#    'release_year': '2020',
#    'id_song': '4yffABDkB5A9flvr9vQFck'},
#   {'artist': 'Tame Impala',
#    'genre': 'rock',
#    'song_name': 'One More Hour',
#    'release_year': '2020',
#    'id_song': '0mO6oS60RST2sWmN2FKknP'},
#   {'artist': 'Will Paquin',
#    'genre': 'rock',
#    'song_name': 'Chandelier',
#    'release_year': '2020',
#    'id_song': '4ENgK9ehJ9PxxrjY2iEH1j'},
#   {'artist': 'mgk',
#    'genre': 'rock',
#    'song_name': 'forget me too (feat. Halsey)',
#    'release_year': '2020',
#    'id_song': '1VSuFS7PahCN3SWbOcQ98m'},
#   {'artist': 'mgk',
#    'genre': 'rock',
#    'song_name': 'bloody valentine',
#    'release_year': '2020',
#    'id_song': '6mADjHs6FXdroPzEGW6KVJ'},
#   {'artist': 'Tame Impala',
#    'genre': 'rock',
#    'song_name': 'Lost In Yesterday',
#    'release_year': '2020',
#    'id_song': '5JWPUEov2wlX7c0jhYZpeB'},
#   {'artist': 'Bombay Bicycle Club',
#    'genre': 'rock',
# ...
#   {'artist': 'Bryson Tiller',
#    'genre': 'r&b',
#    'song_name': 'Always Forever',
#    'release_year': '2020',
#    'id_song': '1LV5cAo02H8h5YlZNcjULM'},
#   {'artist': 'Tink',
#    'genre': 'r&b',
#    'song_name': 'Bottom Bitch',
#    'release_year': '2020',
#    'id_song': '5zAuk07JCI2ZxZch24ZCrS'},
#   {'artist': 'Masego',
#    'genre': 'r&b',
#    'song_name': 'Silver Tongue Devil',
#    'release_year': '2020',
#    'id_song': '6Ap0yGl178iQGuMoXUloVP'},
#   {'artist': 'Tems',
#    'genre': 'r&b',
#    'song_name': 'Ice T',
#    'release_year': '2020',
#    'id_song': '4vcUf8YqLi1mDeT9c0Wo6f'},
#   {'artist': 'Jhené Aiko',
#    'genre': 'r&b',
#    'song_name': 'None Of Your Concern (feat. Big Sean)',
#    'release_year': '2020',
#    'id_song': '75MSZRbAbQuzfUV3Pefvut'},
#   {'artist': 'Victoria Monét',
#    'genre': 'r&b',
#    'song_name': 'We Might Even Be Falling In Love (Interlude)',
#    'release_year': '2020',
#    'id_song': '4rCuwgRRKaIiHlHDc8Bga6'},
#   {'artist': 'Kehlani',
#    'genre': 'r&b',
#    'song_name': 'Can You Blame Me (feat. Lucky Daye)',
#    'release_year': '2020',
#    'id_song': '12xVuIohhHSklxvi1ItKGA'},
#   {'artist': 'Ella Mai',
#    'genre': 'r&b',
#    'song_name': 'Not Another Love Song',
#    'release_year': '2020',
#    'id_song': '5XqDJFVCyRTm5J7cIfRmR1'},
#   {'artist': 'Jordan Rakei',
#    'genre': 'r&b',
#    'song_name': 'Borderline',
#    'release_year': '2020',
#    'id_song': '5rcGQIrv6eUIyCBfWga363'},
#   {'artist': 'Teyana Taylor',
#    'genre': 'r&b',
#    'song_name': 'How You Want It? (feat. King Combs)',
#    'release_year': '2020',
#    'id_song': '28WNotZoSqhjFHPwaeiFLA'},
#   {'artist': 'PARTYNEXTDOOR',
#    'genre': 'r&b',
#    'song_name': 'SPLIT DECISION',
#    'release_year': '2020',
#    'id_song': '7BY2h0RUgeenWrnbwPr0Kt'},
#   {'artist': 'Lithe',
#    'genre': 'r&b',
#    'song_name': 'Pessimist',
#    'release_year': '2020',
#    'id_song': '0JWA4NaSOa1mZfLyNvZLQW'},
#   {'artist': 'Summer Walker',
#    'genre': 'r&b',
#    'song_name': 'My Affection (with PARTYNEXTDOOR)',
#    'release_year': '2020',
#    'id_song': '2aSM4sbNN7cSmpYOG0sf46'},
#   {'artist': 'Blxst',
#    'genre': 'r&b',
#    'song_name': 'Overrated',
#    'release_year': '2020',
#    'id_song': '6Fc9IYSkbmVwv4dlzn8hJb'},
#   {'artist': 'Ojerime',
#    'genre': 'r&b',
#    'song_name': 'Give It Up 2 Me',
#    'release_year': '2020',
#    'id_song': '3X7wVYr4XpzGgoXmQVnrJo'},
#   {'artist': 'H.E.R.',
#    'genre': 'r&b',
#    'song_name': 'Comfortable',
#    'release_year': '2020',
#    'id_song': '3f3cliOygeuUpGRwdohy12'},
#   {'artist': 'SZA',
#    'genre': 'r&b',
#    'song_name': 'Good Days',
#    'release_year': '2020',
#    'id_song': '1bWh6WbYzSFxsOKzE4EpUu'},
#   {'artist': 'Cleo Sol',
#    'genre': 'r&b',
#    'song_name': 'Young Love',
#    'release_year': '2020',
#    'id_song': '4UpBPaIMx7OoFpjeNdXfMn'},
#   {'artist': 'Chris Brown',
#    'genre': 'r&b',
#    'song_name': 'City Girls',
#    'release_year': '2020',
#    'id_song': '1rJUbH0v2E8t1GY4OAUTeC'},
#   {'artist': 'Gabzy',
#    'genre': 'r&b',
#    'song_name': 'As Friends',
#    'release_year': '2020',
#    'id_song': '5xfLJShg04bODHnt1MJyhD'},
#   {'artist': 'Brent Faiyaz',
#    'genre': 'r&b',
#    'song_name': 'Bluffin',
#    'release_year': '2020',
#    'id_song': '3detfCDz7x2G34sKD1XzA6'},
#   {'artist': 'Orion Sun',
#    'genre': 'r&b',
#    'song_name': 'Mirage',
#    'release_year': '2020',
#    'id_song': '1w327AHTCoChRIkJUprAnV'},
#   {'artist': 'KAMAUU',
#    'genre': 'r&b',
#    'song_name': 'MANGO (feat. Adi Oasis)',
#    'release_year': '2020',
#    'id_song': '384TJj6XyHUyNlCbdgm6Sz'},
#   {'artist': 'Lianne La Havas',
#    'genre': 'r&b',
#    'song_name': 'Bittersweet - Radio Edit',
#    'release_year': '2020',
#    'id_song': '7CNtRYYyhNJKXFr2bQ5rv2'},
#   {'artist': 'Drake',
#    'genre': 'r&b',
#    'song_name': 'Not You Too (feat. Chris Brown)',
#    'release_year': '2020',
#    'id_song': '6GVZ7A3IWkPNuG5FdcRE7O'},
#   {'artist': 'PARTYNEXTDOOR',
#    'genre': 'r&b',
#    'song_name': 'EYE ON IT',
#    'release_year': '2020',
#    'id_song': '6N994zHEhtefaMp0mIuMrK'},
#   {'artist': 'Lola Young',
#    'genre': 'r&b',
#    'song_name': 'Pick Me Up',
#    'release_year': '2020',
#    'id_song': '30jct5HzIetNY4IGbrnQKz'},
#   {'artist': 'Jessie Reyez',
#    'genre': 'r&b',
#    'song_name': 'IMPORTED (with 6LACK)',
#    'release_year': '2020',
#    'id_song': '2shEeQzAAL3nnOXfB5pJXx'},
#   {'artist': 'The Silhouettes Project',
#    'genre': 'r&b',
#    'song_name': 'At the Bay',
#    'release_year': '2020',
#    'id_song': '41pbH3pJ5E8EjmeyAbJVGu'},
#   {'artist': 'Daniel Caesar',
#    'genre': 'r&b',
#    'song_name': 'Made to Fall in Love',
#    'release_year': '2020',
#    'id_song': '36h1hoNVjKcsLUH2NzGmPj'},
#   {'artist': 'Jhené Aiko',
#    'genre': 'r&b',
#    'song_name': 'Triggered (freestyle)',
#    'release_year': '2020',
#    'id_song': '3zPgAKn5tbmCuCKrR3r7qE'},
#   {'artist': 'Dutch Melrose',
#    'genre': 'r&b',
#    'song_name': 'Sleepless',
#    'release_year': '2020',
#    'id_song': '3omOkLNDoM6G5Ggrh9MPXb'},
#   {'artist': 'Victoria Monét',
#    'genre': 'r&b',
#    'song_name': 'Experience',
#    'release_year': '2020',
#    'id_song': '2oap3QptGISyIvwKpnJJId'},
#   {'artist': 'Qendresa',
#    'genre': 'r&b',
#    'song_name': "Don't Stop",
#    'release_year': '2020',
#    'id_song': '597QyIjFzPHQt4ZxpSxRW5'},
#   {'artist': 'GIVĒON',
#    'genre': 'r&b',
#    'song_name': 'Vanish',
#    'release_year': '2020',
#    'id_song': '0ECWkqtSIryUYVjyJMr0yA'},
#   ...],
#  {'24kGoldn',
#   'A Day To Remember',
#   'AC/DC',
#   'AJR',
#   'AP Dhillon',
#   'Aaryan Shah',
#   'Abraham Afewerki',
#   'Adele',
#   'Admas',
#   'Against The Current',
#   'Agust D',
#   'Alabaster DePlume',
#   'Alesso',
#   'Alewya',
#   'Alex Isley',
#   'Alexander 23',
#   'Alina Baraz',
#   'All Time Low',
#   'Amaarae',
#   'Amaria',
#   'Amy Winehouse',
#   'Angus Grove',
#   'Anne-Marie',
#   'Architects',
#   'Ariana Grande',
#   'Arlo Parks',
#   'Arne Torvik Trio',
#   'AronChupa',
#   'Arrows in Action',
#   'Art Blakey & The Jazz Messengers',
#   'Art Hirahara',
#   'Ashe',
#   'Asiah',
#   'Athletic Progression',
#   'Ava Max',
#   'Awaken I Am',
#   'Ayra Starr',
#   'Ayọ',
#   'BADBADNOTGOOD',
#   'BLACKPINK',
#   'BRKN LOVE',
#   'BTS',
#   'Bad Nerves',
#   'Bailey Zimmerman',
#   'Baptiste Herbin',
#   'Beach Bunny',
#   'Beck',
#   'Becky Hill',
#   'Ben Webster',
#   'Benny Goodman Quartet',
#   'Benson Boone',
#   'Betty Booom',
#   'Bibi Tanga & The Selenites',
#   'Biffy Clyro',
#   'Biig Piig',
#   'Bill Charlap Trio',
#   'Billie Eilish',
#   'Billy Idol',
#   'Black Eyed Peas',
#   'Black Stone Cherry',
#   'Bladverk Band',
#   'Bluey',
#   'Blxst',
#   'Bombay Bicycle Club',
#   'Boogie Belgique',
#   'Boozoo Bajou',
#   'Brent Faiyaz',
#   'Bring Me The Horizon',
#   'Briston Maroney',
#   'Brothers Moving',
#   'Bruno Mars',
#   'Bryson Tiller',
#   'COIN',
#   'Cafuné',
#   'Calvin Harris',
#   'Cande y Paulo',
#   'Caro Emerald',
#   'Carol Albert',
#   'Carsten Dahl',
#   'Caskets',
#   'Catching Flies',
#   'Charli xcx',
#   'Charlotte Day Wilson',
#   'Chase Atlantic',
#   'Che Ecru',
#   'Chihiro Yamanaka',
#   'Chloe x Halle',
#   'Chris Brown',
#   'Chris Norman',
#   'Chris Standring',
#   'Chris Stapleton',
#   'Chubby Checker',
#   'Cigarettes After Sex',
#   'Cissy Street',
#   'Citizen Soldier',
#   'Clairo',
#   'Clean Bandit',
#   'Cleo Sol',
#   'Clube no norte',
#   'Cody Currie',
#   'Colby Brock',
#   'Coldplay',
#   'Conan Gray',
#   'Conor Albert',
#   'Cory Marks',
#   'Cory Wong',
#   'DARGZ',
#   'DAY6',
#   'DEMONDICE',
#   'DESTIN CONRAD',
#   'DON BROCO',
#   'Dabeull',
#   'Daniel Caesar',
#   'Daniel Di Angelo',
#   'Danny Walgreen',
#   'Darci',
#   'Dave Wave',
#   'David Guetta',
#   'David Walters',
#   'Davishmar',
#   'Dayglow',
#   'De-Phazz',
#   'DeJ Loaf',
#   'Dean Blunt',
#   'Deftones',
#   'Del Water Gap',
#   'Diana Krall',
#   'Dijon',
#   'Diplo',
#   'Dirty Loops',
#   'Doja Cat',
#   'Don Toliver',
#   'Doris Day',
#   'Drake',
#   'Dreamer Isioma',
#   'Drew Milner',
#   'Dua Lipa',
#   'Duckwrth',
#   'Duponte et Duponte',
#   'Duran Duran',
#   'Durand Jones & The Indications',
#   'Dutch Melrose',
#   'Dutty Moonshine Big Band',
#   'Dzihan & Kamien',
#   'EKKSTACY',
#   'ENHYPEN',
#   'ENNY',
#   'Ed Sheeran',
#   'Eddie Condon',
#   'Edward France',
#   'Ella Fitzgerald',
#   'Ella Mai',
#   'Ellie Goulding',
#   'Ellie Manne',
#   'Elton John',
#   'Elvine Harley',
#   'Elvis Costello & The Attractions',
#   'Emil Brandqvist',
#   'Emma-Jean Thackray',
#   'Emmet Cohen',
#   'Emotional Oranges',
#   'Erroll Garner',
#   'Espen Eriksen Trio',
#   'Eyedress',
#   'FAVE',
#   'Falling In Reverse',
#   'Fievel Is Glauque',
#   'Fiona Apple',
#   'Fireboy DML',
#   'Five Finger Death Punch',
#   'Floating Points',
#   'Flora Martínez',
#   'Flyte',
#   'Foo Fighters',
#   'Forest Blakk',
#   'Frances Forever',
#   'French Police',
#   'Friday Pilots Club',
#   'Fujii Kaze',
#   'Funky Times',
#   'Future Islands',
#   'G-Eazy',
#   'GIVĒON',
#   'Gabzy',
#   'Galantis',
#   'Gary Bartz',
#   'George Alec',
#   'Gerardo Frisina',
#   'Gianni Brezzo',
#   'Girlhood',
#   'Glass Animals',
#   'Glenn Gatsby',
#   'GoGo Penguin',
#   'Good Kid',
#   'Gotts Street Park',
#   'Grace Carey',
#   'Gracie Abrams',
#   'Greentea Peng',
#   'Greg Foat',
#   'Gregory Porter',
#   'Greta Van Fleet',
#   'Grimes',
#   "Guns N' Roses",
#   'H.E.R.',
#   'Hailu Mergia',
#   'Halsey',
#   'Hara Noda',
#   'Hederosgruppen',
#   'Hiatus Kaiyote',
#   'Holborns',
#   'Holding Absence',
#   'Hollow Ship',
#   'Hot Mulligan',
#   'Hotel Ugly',
#   'I DONT KNOW HOW BUT THEY FOUND ME',
#   'IDLES',
#   'ITZY',
#   'Ibrahim Maalouf',
#   'Imagine Dragons',
#   'Immanuel Wilkins',
#   'Inayah',
#   'Inhaler',
#   'Ionn Blignault',
#   'Iron Maiden',
#   'Izzy Wise',
#   'JAWNY',
#   'JP Saxe',
#   'Jack Harlow',
#   'Jacob De La Rose',
#   'Jake Bugg',
#   'James Blake',
#   'James Jackson Jazz Trio',
#   'James Marriott',
#   'James Vickery',
#   'Japanese Breakfast',
#   'Jasleen Royal',
#   'Jason Derulo',
#   'Jax Jones',
#   'Jazmine Sullivan',
#   'Jazzy Coffee',
#   'Jazzystics',
#   'Jenevieve',
#   'Jessie Reyez',
#   'Jesus Molina',
#   'Jhené Aiko',
#   'Jill Barber',
#   'Jimmy Heath',
#   'Joao Donato',
#   'Joel Corry',
#   'Joesef',
#   'John Coltrane',
#   'John Engels',
#   'John Rae',
#   'Johnathan Blake',
#   'Joji',
#   'Jon Belle',
#   'Jonasu',
#   'Jonny Libonate',
#   'Jordan Rakei',
#   'Jordan Ward',
#   'Jorja Smith',
#   'Joy Crookes',
#   'Jules Gaia',
#   'June Freedom',
#   'Jung Kook',
#   'Jungle',
#   'K/DA',
#   'KALEO',
#   'KAMAUU',
#   'Kaash Paige',
#   "Kahil El'Zabar",
#   'Kali Uchis',
#   'Kamasi Washington',
#   'Kandace Springs',
#   'Katy Perry',
#   'Kay Lohman',
#   'Keanan Field Group',
#   'Keanu Bicol',
#   'Kehlani',
#   'Keith Urban',
#   'Kevin Walkman',
#   'Khalid',
#   'Khamari',
#   'Khruangbin',
#   'Kiefer',
#   'Kim Waters',
#   'Kings of Leon',
#   'Kip Moore',
#   'Klugzone',
#   'Kokoroko',
#   'Kygo',
#   'Kyle Sparkman',
#   'L.A.X',
#   'LAUREL',
#   'LEISURE',
#   'LISA',
#   'LPB Poody',
#   'Lady Blackbird',
#   'Lady Gaga',
#   'Lana Del Rey',
#   'Lars Danielsson',
#   'Laufey',
#   'Lawson Rollins',
#   'Lee Bendroth',
#   'Lee Brice',
#   'Leon Bridges',
#   'Les Sabler',
#   'Letdown.',
#   'Lewis Capaldi',
#   'Lianne La Havas',
#   'Lighthouse Lounge Band',
#   'Lil Nas X',
#   'Limp Bizkit',
#   'Lithe',
#   'Little Dragon',
#   'Little Mix',
#   'Little Violet',
#   'Loathe',
#   'Lola Young',
#   'Loona',
#   'Lord Huron',
#   'Lorde',
#   'Lost Frequencies',
#   'Louis Dunford',
#   'Lovejoy',
#   'Lovely Peaches',
#   'Lucky Daye',
#   'Lynyrd Skynyrd',
#   'MARINA',
#   'MICHELLE',
#   'MORGAN',
#   'Madeleine Peyroux',
#   'Magdalena Bay',
#   'Maggie Lindemann',
#   'Magpie Jazz Trio',
#   'Majestic',
#   'Mandevilla',
#   'Marcin Wasilewski Trio',
#   'Marcus King',
#   'Mareux',
#   'Mariah the Scientist',
#   'Mario Winans',
#   'Mark Roswell Trio',
#   'Maroon 5',
#   'Marshmello',
#   'Martin Landström',
#   'Martina DaSilva',
#   'Mary Jane Girls',
#   'Masego',
#   'Matt Carmichael',
#   'Matt Corby',
#   'Matt Dusk',
#   'Melody Gardot',
#   'Memo Boy',
#   'Mereba',
#   'Metallica',
#   'Mezzoforte',
#   'Michel Colombier',
#   'Miley Cyrus',
#   'Milky Chance',
#   'Mimi Webb',
#   'Mista Trick',
#   'Montell Fish',
#   'Moonlight Jazz Trio',
#   'Moreno Jazz Band',
#   'Move 78',
#   'Mr Jukes',
#   'Myele Manzanza',
#   'Måneskin',
#   'NEIKED',
#   'NO CIGAR',
#   'Nala Sinephro',
#   'Nation of Language',
#   'Ne-Yo',
#   'Nea',
#   'Nessa Barrett',
#   'Nevertel',
#   'New Constellations',
#   'Nikitch',
#   'Nils Petter Molvær',
#   'Nina Simone',
#   'Nirvana',
#   'Noname',
#   'Normani',
#   'Nothing But Thieves',
#   'Nouveau Jazz Trio',
#   'Nubiyan Twist',
#   'Nubya Garcia',
#   'ODIE',
#   'OR3O',
#   'Ojerime',
#   'Oklou',
#   'Old Mervs',
#   'Oliver Tree',
#   'Olivia Dean',
#   'Olivia Rodrigo',
#   'Omah Lay',
#   'Omar',
#   'OneRepublic',
#   'Oracle Sisters',
#   'Orion Sun',
#   'Oscar Peterson Trio',
#   'Ozzy Osbourne',
#   'P!nk',
#   'PARTYNEXTDOOR',
#   'Palaye Royale',
#   'Panchiko',
#   'Papa Roach',
#   'Paris Texas',
#   'Parov Stelar',
#   'Peach Pit',
#   'Pearl Jam',
#   'Peggy Lee',
#   'Pentire',
#   'Phoebe Bridgers',
#   'Pink Martini',
#   'Pink Siifu',
#   'PinkPantheress',
#   'Pino Palladino',
#   'Pip Millett',
#   'Pisk',
#   'Point North',
#   'Poppy',
#   'Portraits in Jazz',
#   'Post Malone',
#   'Purple Disco Machine',
#   'Q',
#   'Qendresa',
#   'Quantic',
#   'Quincy Jones',
#   'RAYE',
#   'ROSÉ',
#   'RUBII',
#   'RYUSENKEI',
#   'Radiohead',
#   "Rag'n'Bone Man",
#   'Rain City Drive',
#   'Ramiro Pinheiro',
#   'Ray Charles',
#   'Ray Royston',
#   'Regard',
#   'Rema',
#   'Remi Wolf',
#   'Richard Ashcroft',
#   'Rikard From',
#   'Riton',
#   'Robert Elovsson',
#   'Roger Strauss',
#   'Ronald Langestraat',
#   'Roy Williams',
#   'Royal Blood',
#   'Ruby Rushton',
#   'Ruhi Erdogan',
#   'Russ',
#   'Ryo Fukui',
#   'RØRY',
#   'SAULT',
#   'SPINALL',
#   'STR4TA',
#   'SWIM',
#   'SZA',
#   'Sabrina Carpenter',
#   'Saint Motel',
#   'Sam Hunt',
#   'Sam Smith',
#   'Sam Wills',
#   'Samara Joy',
#   'Sasha Keable',
#   'Selena Gomez',
#   'Sevyn Streeter',
#   'Shakatak',
#   'Shane Codd',
#   'Shanice Green',
#   'Shawn Mendes',
#   'Sigala',
#   'Simon Westman Trio',
#   'Simple Plan',
#   'Sir Chloe',
#   'Skeete',
#   'Slow Pulp',
#   'Snazzback',
#   'Snoh Aalegra',
#   'Solence',
#   "Somebody's Child",
#   'Sonder',
#   'Sons Of Kemet',
#   'Sophie Nichols',
#   'Southside Trio',
#   'St Germain',
#   'Stan Van Outen',
#   'Stellar',
#   'Stray Kids',
#   'Sub Urban',
#   'Summer Walker',
#   'Sun Room',
#   'SunPalace',
#   'Surprise Chef',
#   'Svaneborg Kardyb',
#   "Swing'it",
#   'Swingrowers',
#   'T. P. Orchestre Poly-Rythmo',
#   'THE ANXIETY',
#   'THE DRIVER ERA',
#   'THE TAKE VIBE E.P.',
#   'TWICE',
#   'Tame Impala',
#   'Tate McRae',
#   'Taylor Swift',
#   'Teddy Swims',
#   'Tems',
#   'Terrace Martin',
#   'Teyana Taylor',
#   'The 1975',
#   'The 8-Bit Big Band',
#   'The Allergies',
#   'The Bahama Soul Club',
#   'The Beefs',
#   'The Black Keys',
#   'The Blue Stones',
#   'The Bridge City Sinners',
#   'The Chalkeaters',
#   'The Chats',
#   'The Cooltrane Quartet',
#   'The Coral',
#   'The Fearless Flyers',
#   'The French Note',
#   'The Happy Fits',
#   'The Home Team',
#   'The Marías',
#   'The Neighbourhood',
#   'The Offspring',
#   'The Orion Experience',
#   'The Plot In You',
#   'The Rare Occasions',
#   'The Reytons',
#   'The Rolling Stones',
#   'The Royston Club',
#   'The S.P.Joy',
#   'The Silhouettes Project',
#   'The Snuts',
#   'The Sorcerers',
#   "The Speakeasies' Swing Band!",
#   'The Strokes',
#   'The Sweetgreens',
#   'The Swinghoppers',
#   'The Uptown Players',
#   'The Weeknd',
#   'The Who',
#   'Theophilus London',
#   'Thierry Marchal',
#   'Thomas Dutronc',
#   'Thomas Rhett',
#   'Those Damn Crows',
#   'Thundercat',
#   'Tink',
#   'Tiwa Savage',
#   'Tiësto',
#   'Tom Grennan',
#   'Tom Misch',
#   'Tom Morello',
#   'Tony Bennett',
#   'Tory Lanez',
#   'Triosence',
#   'Trippie Redd',
#   'Tuberokoto',
#   'Twenty One Pilots',
#   'Tyler, The Creator',
#   'Téo Freire',
#   'ULTRA SUNN',
#   'Ultravox',
#   'Underground Canopy',
#   'VIOLENT VIRA',
#   'VOILÀ',
#   'Varra',
#   'Venna',
#   'Victoria Monét',
#   'Vince Guaraldi Trio',
#   'Vincent Herring',
#   'Vincent Ingala',
#   'Vistas',
#   'Vitor José Fonseca',
#   'Volbeat',
#   'WILLOW',
#   'Wage War',
#   'Wallows',
#   'Wanda Jackson',
#   'Wande Coal',
#   'Weathers',
#   'Web Web',
#   'Wesley Joseph',
#   'Wet Leg',
#   'Whitney Houston',
#   'Wilderado',
#   'Will Paquin',
#   'With Confidence',
#   'Wizkid',
#   'Wyldest',
#   'Ximena & Antonio',
#   'YUNGBLUD',
#   'Yadava',
#   'Yazmin Lacey',
#   'Yebba',
#   'Yung Bleu',
#   'Yung Gravy',
#   'Yusuf / Cat Stevens',
#   'Yves Tumor',
#   'Zach Hood',
#   'Zara Larsson',
#   'Zoe Wees',
#   'Zubi',
#   'bbno$',
#   'beabadoobee',
#   'corto.alto',
#   'flipturn',
#   'girl in red',
#   'grandson',
#   'hard life',
#   'julie',
#   'jxdn',
#   'late night drive home',
#   'melvitto',
#   'mgk',
#   'rum.gold',
#   'twocolors'})

# %% [markdown]
# ---
# ## Data Extraction: Last.fm API
# ---
#
# The Last.fm API is used to extract information about artist bios, popularity, and similar artists, using Spotify extraction.
#
# The Last.fm API requires authentication using an `API key`, which you can find in the API documentation available here:
# [Last.fm Web API](https://www.last.fm/api)

# %%
# after reviewing the Last.fm API documentation the API_Key and URL are used

API_KEY = 'daf9398fbb92abf81e906df604450de3' # replace with 'insert your Client_ID here'
BASE_URL = 'http://ws.audioscrobbler.com/2.0/'

# %%
set_artists = set(artists)
list_artists_spotify = list(set_artists) # convert the set to a list again

# %% [markdown]
# ---
# ### Extraction of complementary information about artists extracted from the Spotify API
# ---

# %%
# function that extracts the clean text from the bio

def clean_bio(bio):
    soup = BeautifulSoup(bio, "html.parser")
    return soup.get_text().strip()

# a function is defined for extracting the complementary information with the parameters: list of artists and API authentication

def extraction_artist(list_artists_spotify, BASE_URL, API_KEY):
    artist_data = []

    for i in list_artists_spotify:
        params_info = {
            'method': 'artist.getinfo',
            'artist': i,
            'api_key': API_KEY,
            'format': 'json'
            }
        response_info = requests.get(BASE_URL, params=params_info)
        data_info = response_info.json()

        try:
            bio_summary = data_info['artist'].get('bio', {}).get('summary', 'No data')
            bio_summary = clean_bio(bio_summary)
            if not bio_summary or bio_summary == '' or bio_summary == 'No data':
                bio_summary = 'No data'
        except KeyError:
            bio_summary = 'No data'

        try:
            listeners = data_info['artist'].get('stats', {}).get('listeners', 'No data')
            if 'stats' == None:
                listeners = 'No data'
        except KeyError:
            listeners = 'No data'

        try:
            play = data_info['artist'].get('stats', {}).get('playcount', 'No data')
            if 'stats' == None:
                play = 'No data'
        except KeyError:
            play = 'No data'

        artist_data.append({
            'artist': i,
            'biography': bio_summary,
            'listeners': listeners,
            'playcount': play
        })

    df_last = pd.DataFrame(artist_data)
    print(f'format data frame artists: {df_last.shape}')
    print(df_last.head()) # control print to know what data we are extracting

    df_last.to_csv(f'../03_data/artists_data.csv') # create a CSV file with the artists' information

# %%
# the function is called with the necessary parameters

extraction_artist(list_artists_spotify, BASE_URL, API_KEY)
# Out:
# format data frame artists: (624, 4)
#           artist                                          biography listeners  \
# 0  Summer Walker  Summer Marjani Walker is an American singer an...   1573087
# 1           ODIE  Odie is the name of more than one artist: 1) C...    539924
# 2     Lola Young  Lola Young is an R&B-rooted, stylistically dyn...    966200
# 3     ULTRA SUNN  ULTRA SUNN is a contemporary band from Brussel...    169950
# 4  David Walters  David Walters, is a French singer-songwriter, ...     47314
#
#   playcount
# 0  93855000
# 1   8149834
# 2  16874372
# 3   1883823
# 4    274691

# %% [markdown]
# ---
# ### Extraction of similar artists
# ---

# %%
# function that extracts similar artists, which uses as parameters the list of artists previously saved in the list

def extraction_similar_artist(list_artists_spotify, BASE_URL, API_KEY):
    similar_artists = []
    
    for i in list_artists_spotify:
        params_similar = {
            'method': 'artist.getsimilar',
            'artist': i,
            'api_key': API_KEY,
            'format': 'json'
            }
        response_similar = requests.get(BASE_URL, params=params_similar)
        data_similar = response_similar.json()

        try:
            for artist in data_similar['similarartists']['artist'][0:5]:
                similar_artists.append((i, artist['name']))
        except KeyError:
            similar_artists.append((i, 'No data'))

        time.sleep(0.2)

    df_similar = pd.DataFrame(similar_artists)
    print(f'format data frame similar artists: {df_similar.shape}')
    print(df_similar.head()) # print that controls the information we are extracting

    df_similar.to_csv(f'../03_data/similar_artist_data.csv') # create a CSV file with the extracted information

# %%
# the function is called with the necessary parameters

extraction_similar_artist(list_artists_spotify, BASE_URL, API_KEY)
# Out:
# format data frame similar artists: (3100, 2)
#                0                     1
# 0  Summer Walker  Mariah the Scientist
# 1  Summer Walker            Jhené Aiko
# 2  Summer Walker               Kehlani
# 3  Summer Walker                   SZA
# 4  Summer Walker            Ari Lennox

# %% [markdown]
# ### Phase 2: Database Modeling
#
# This phase includes data modeling and loading:
#
# - Relational model design: The main entities (artists, songs, genres, years, etc.) and their relationships are defined
#
# - Database creation: The model is automatically implemented in Python
#
# - Data loading: Inserting data from the CSV files into the corresponding tables using Python
#
# ---

# %% [markdown]
# ## Connecting to MySQL: Creating a Database
# ---
#
# Creating Python/SQL scripts to create the database and tables and insert data into the database

# %%
def create_database():
    #MySQL connection
    cnx = mysql.connector.connect(user='root', 
                                  password='AlumnaAdalab',
                                  host='127.0.0.1')
    
    mycursor = cnx.cursor()
    try:
        mycursor.execute("CREATE DATABASE IF NOT EXISTS db_cozy_music")
        print(mycursor)
    except mysql.connector.Error as err:
        print(err)
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)
    finally:
        # cierra cursor y conexión
        if 'mycursor' in locals() and mycursor is not None:
            mycursor.close()
        if 'cnx' in locals() and cnx.is_connected():
            cnx.close()
            print("Database connection closed.")

# %%
create_database()
# Out:
# CMySQLCursor: CREATE DATABASE IF NOT EXISTS db_cozy_mu..
# Database connection closed.

# %% [markdown]
# ---
# ### Creating the 'Artists', 'Songs', and 'Similar Artists' tables
# ---

# %%
def mysql_conn():
    return mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='db_cozy_music')

# %%
# Artist table: Includes artist information as id_artist, artist_name, bio, listener count, playcount
# Songs table: Includes artist information as id_song, song_name, id_artist, genre, release_year
# Similar_artists table: Includes artist information as id_artist, similar_artists

def create_tables():
    cnx = mysql_conn()
    mycursor = cnx.cursor()
    try:
        mycursor.execute("""
                        CREATE TABLE artist (
                        id_artist INT PRIMARY KEY AUTO_INCREMENT, 
                        artist_name VARCHAR(255), 
                        biography TEXT, 
                        listeners INT, 
                        playcount INT)""")
                        
        mycursor.execute("""
                        CREATE TABLE songs (
                        id_song VARCHAR(100) PRIMARY KEY,
                        song_name VARCHAR(255), 
                        id_artist INT, 
                        genre VARCHAR(50),
                        release_year INT,
                        FOREIGN KEY (id_artist) REFERENCES artist(id_artist) 
                        )""")
        
        mycursor.execute("""
                        CREATE TABLE similar_artists (
                        id_primary_artist INT, 
                        similar_artist VARCHAR(255),
                        FOREIGN KEY (id_primary_artist) REFERENCES artist(id_artist)
                        )""")
        
        print(mycursor)
    except mysql.connector.Error as err:
        print(err)
        print("Error Code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)
    finally:
        # close cursor and connection
        if 'mycursor' in locals() and mycursor is not None:
            mycursor.close()
        if 'cnx' in locals() and cnx.is_connected():
            cnx.close()
            print("Database connection closed.")

# %%
create_tables()
# Out:
# CMySQLCursor:
#                         CREATE TABLE si..
# Database connection closed.

# %%
conn = mysql_conn()
cursor = conn.cursor()

sql = '''ALTER TABLE artist MODIFY playcount BIGINT;'''
cursor.execute(sql)
result = cursor.fetchone()
print("Table 'artist' structure:")  
print(result[1])  # Print the CREATE TABLE statement for the 'artist' table

conn.commit()
cursor.close()
conn.close()

# %% [markdown]
# ---
# ### Inserting data into the 'Artists' table
# ---

# %%
def insert_artist_data(df):
    conn = mysql_conn()
    cursor = conn.cursor()

    for _, row in df.iterrows():
        # cleaning: converts 'No data' to None for listeners and playcount
        listeners = None if row['listeners'] == 'No data' else row['listeners']
        playcount = None if row['playcount'] == 'No data' else row['playcount']
        sql = """
        INSERT INTO artist (artist_name, biography, listeners, playcount)
        VALUES (%s, %s, %s, %s)
        """
        cursor.execute(sql, (row['artist'], row['biography'], listeners, playcount))

    conn.commit()
    cursor.close()
    conn.close()

# %%
# read the CSV file
df = pd.read_csv('../03_data/artists_data.csv')

# %%
insert_artist_data(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 insert_artist_data(df)
#
# Cell In[65], line 8, in insert_artist_data(df)
#       5 for _, row in df.iterrows():
#       6     # cleaning: converts 'No data' to None for listeners and playcount
#       7     listeners = None if row['listeners'] == 'No data' else row['listeners']
# ----> 8     playcount = None if row['playcount'] == 'No data' else row['playcount'].replace(',', '').strip()
#       9     sql = """
#      10     INSERT INTO artist (artist_name, biography, listeners, playcount)
#      11     VALUES (%s, %s, %s, %s)
#      12     """
#      13     cursor.execute(sql, (row['artist'], row['biography'], listeners, playcount))
#
# AttributeError: 'int' object has no attribute 'replace'

# %% [markdown]
# ---
# ### Inserción de data en la tabla 'Artistas similares'
# ---

# %%
def insert_similar_artists(df):
    conn = mysql_conn()
    cursor = conn.cursor()

    # 3. mapeo de nombre de artista a id_artist
    cursor.execute("SELECT id_artist, artist_name FROM artist")
    artist_map = {name.lower(): id_ for id_, name in cursor.fetchall()}

    # 4. prepara los datos válidos para insertar
    records_to_insert = []
    for _, row in df.iterrows():
        id_primary_artist = artist_map.get(str(row['primary_artist']).lower())
        similar_artist = row['similar_artist']
        if id_primary_artist is not None and pd.notnull(similar_artist):
            records_to_insert.append((id_primary_artist, similar_artist))
        else:
            print(f"Advertencia: No se encontró el artista '{row['primary_artist']}' en la base de datos. Fila omitida.")

    # 5. inserta todos los registros válidos de una vez
    if records_to_insert:
        sql = """
        INSERT INTO similar_artists (id_primary_artist, similar_artist)
        VALUES (%s, %s)
        """
        cursor.executemany(sql, records_to_insert)
        conn.commit()
        print(f"{cursor.rowcount} filas insertadas en similar_artists.")
    else:
        print("No hay registros válidos para insertar.")

    cursor.close()
    conn.close()

# %%
# 1. leer el CSV (sin encabezados, asignando nombres)
dfs = pd.read_csv('../03_data/similar_artist_data.csv', header=None, names=['primary_artist', 'similar_artist'])

# %%
insert_similar_artists(dfs)
# Out:
# Advertencia: No se encontró el artista '0' en la base de datos. Fila omitida.
# 7365 filas insertadas en similar_artists.

# %% [markdown]
# ---
# ### Inserción de data en la tabla 'Canciones'
# ---

# %%
def insert_songs(df):
    conn = mysql_conn()
    cursor = conn.cursor()

    # 3. mapeo de nombre de artista a id_artist
    cursor.execute("SELECT id_artist, artist_name FROM artist")
    artist_map = {name.lower(): id_ for id_, name in cursor.fetchall()}

    # 4. prepara los datos válidos para insertar
    records_to_insert = []
    for _, row in df.iterrows():
        id_song = row['id_song']
        song_name = row['song_name']
        artist_name = str(row['artist']).lower()
        id_artist = artist_map.get(artist_name)
        genre = row['genre']
        release_year = row['release_year']

        # validaciones básicas
        if id_artist is not None and pd.notnull(id_song) and pd.notnull(song_name):
            records_to_insert.append((id_song, song_name, id_artist, genre, release_year))
        else:
            print(f"Advertencia: No se encontró el artista '{row['artist']}' o datos faltantes en la fila. Fila omitida.")

    # 5. inserta todos los registros válidos por lotes

    if records_to_insert:
        sql = """
        INSERT IGNORE INTO songs (id_song, song_name, id_artist, genre, release_year)
        VALUES (%s, %s, %s, %s, %s)
        """
        batch_size = 500  # se puede ajustar el tamaño según la RAM
        for i in range(0, len(records_to_insert), batch_size):
            batch = records_to_insert[i:i+batch_size]
            cursor.executemany(sql, batch)
            conn.commit()
        print(f"{len(records_to_insert)} filas insertadas en songs.")
    else:
        print("No hay registros válidos para insertar.")

    cursor.close()
    conn.close()

# %%
# 1. leer el CSV
dfso = pd.read_csv('../03_data/songs.csv')

# %%
insert_songs(dfso)
# Out:
# 2400 filas insertadas en songs.

# %% [markdown]
# ---
# ## Conexión con MySQL: Consultas en la Base de Datos (BBDD)
# ---
#
# Ejecutar consultas SQL para responder a preguntas específicas que luego analizaremos.

# %%
#-- I. ¿Cuál es el artista con más popularidad y a qué género pertenece? 
#-- Tomando listeners (seguidores) como medida de popularidad (listeners y playcount colocan a Coldplay de primero)
def most_popular_artist():
    conn = mysql_conn()
    # 2. iniciamos el cursor   
    cursor = conn.cursor()

    # 3. query de ejemplo:
    query = ("""SELECT a.artist_name, s.genre
                FROM songs s
                INNER JOIN artist a USING(id_artist)
                WHERE id_artist = (
                    SELECT id_artist
                    FROM artist
                    ORDER BY listeners DESC
                    LIMIT 1
                );
                """)

    # 4. luego llamamos al método execute() del cursor, al que pasamos como argumento el string que contiene la consulta.
    # De esta manera se ejecuta la consulta en la base de datos y si todo va correctamente, el resultado se almacenará en el cursor.
    cursor.execute(query)

    results = cursor.fetchall()
    cursor.close()
    conn.close()

    df_results = pd.DataFrame(results)
    print(f'The most popular artist is: {df_results.iloc[0, 0]}, and the genre is: {df_results.iloc[0, 1]}.')

# %%
most_popular_artist()
# Out:
# The most popular artist is: The Doors, and the genre is: rock.

# %%
#-- II. ¿En qué año se lanzaron más canciones, 2020 o 2021?

def most_songs_year():
    conn = mysql_conn()
    # 2. iniciamos el cursor   
    cursor = conn.cursor()

    # 3. query de ejemplo:
    query = ("""SELECT release_year, COUNT(id_song) AS total_songs
                FROM songs
                GROUP BY release_year
                ORDER BY total_songs DESC
                LIMIT 1;
                            );
                """)

    # 4. luego llamamos al método execute() del cursor, al que pasamos como argumento el string que contiene la consulta.
    # De esta manera se ejecuta la consulta en la base de datos y si todo va correctamente, el resultado se almacenará en el cursor.
    cursor.execute(query)

    results = cursor.fetchall()
    cursor.close()
    conn.close()

    df_results = pd.DataFrame(results)

    print(f'Year with most songs released: {df_results.iloc[0, 0]}')
    print(f'Total songs released in {df_results.iloc[0, 0]}: {df_results.iloc[0, 1]}')

# %%
most_songs_year()
# Out:
# Year with most songs released: 2020
# Total songs released in 2020: 1104

# %%
#-- III. ¿Cuántas canciones y artistas tenemos en nuestra BBDD? 

def total_songs_artists():
    conn = mysql_conn()
    # 2. iniciamos el cursor   
    cursor = conn.cursor()

    # 3. query de ejemplo:
    query = ("""SELECT COUNT(DISTINCT s.id_song) AS total_songs,
                COUNT(DISTINCT a.id_artist) AS total_artists
                FROM songs s
                JOIN artist a USING(id_artist);
                                """)

    # 4. luego llamamos al método execute() del cursor, al que pasamos como argumento el string que contiene la consulta.
    # De esta manera se ejecuta la consulta en la base de datos y si todo va correctamente, el resultado se almacenará en el cursor.
    cursor.execute(query)

    results = cursor.fetchall()
    cursor.close()
    conn.close()

    df_results = pd.DataFrame(results)

    print(f'The total number of songs in our database is {df_results.iloc[0, 0]}')
    print(f'And the total number of artists is {df_results.iloc[0, 1]}')

# %%
total_songs_artists()
# Out:
# The total number of songs in our database is 2191
# And the total number of artists is 1555

# %%
#-- IV. Ranking géneros con más oyentes y reproducciones de mayor a menor.

def genre_ranking():
    conn = mysql_conn()
    # 2. iniciamos el cursor   
    cursor = conn.cursor()

    # 3. query de ejemplo:
    query = ("""SELECT genre, SUM(listeners) AS total_listeners, SUM(playcount) AS total_playcount
                    FROM artist
                    INNER JOIN songs USING(id_artist)
                    GROUP BY genre
                    ORDER BY total_listeners DESC;
                                                """)

    # 4. luego llamamos al método execute() del cursor, al que pasamos como argumento el string que contiene la consulta.
    # De esta manera se ejecuta la consulta en la base de datos y si todo va correctamente, el resultado se almacenará en el cursor.
    cursor.execute(query)

    results = cursor.fetchall()
    cursor.close()
    conn.close()

    results
    df_results = pd.DataFrame(results)
    df_results.columns = ['Genre', 'Total Listeners', 'Total Playcount']
    return df_results

# %%
genre_ranking()
# Out:
#   Genre Total Listeners Total Playcount
# 0  rock       179173938      3783676305
# 1   r&b        87443481      1307078762
# 2   pop        72240209      1472046695
# 3  jazz        41773152       497608759

# %%
#-- V. Top 5 de artistas más escuchados de cada género y su biografía y artistas similares.

def top_5_artists_genre():
    conn = mysql_conn()
    # 2. iniciamos el cursor   
    cursor = conn.cursor()

    # 3. query:
    query = ("""SELECT 
                    a.artist_name,
                    s.genre,
                    CAST(COALESCE(a.listeners, 0) AS UNSIGNED) AS total_listeners,
                    a.biography,
                    GROUP_CONCAT(DISTINCT sa.similar_artist SEPARATOR ', ') AS similar_artists
                FROM artist a
                INNER JOIN songs s ON a.id_artist = s.id_artist
                LEFT JOIN similar_artists sa ON sa.id_primary_artist = a.id_artist
                WHERE
                    (
                        SELECT COUNT(DISTINCT a2.id_artist)
                        FROM artist a2
                        INNER JOIN songs s2 ON a2.id_artist = s2.id_artist
                        WHERE s2.genre = s.genre AND a2.listeners > a.listeners
                    ) < 5
                GROUP BY a.artist_name, s.genre, a.listeners, a.biography
                ORDER BY s.genre, a.listeners DESC;
                                                """)

    # 4. luego llamamos al método execute() del cursor, al que pasamos como argumento el string que contiene la consulta.
    # De esta manera se ejecuta la consulta en la base de datos y si todo va correctamente, el resultado se almacenará en el cursor.
    cursor.execute(query)

    results = cursor.fetchall()
    cursor.close()
    conn.close()

    df_results = pd.DataFrame(results)
    df_results.columns = ['Artist Name', 'Genre', 'Total Listeners', 'Biography', 'Similar Artists']
    return df_results

# %%
top_5_artists_genre()
# Out:
#           Artist Name Genre  Total Listeners  \
# 0     Louis Armstrong  jazz          2712606
# 1     Ella Fitzgerald  jazz          2642994
# 2         Dean Martin  jazz          2567892
# 3         Ray Charles  jazz          2504622
# 4        Otis Redding  jazz          2190440
# 5   Hank Harpers Trio  jazz                0
# 6        Lorenzo Luca  jazz                0
# 7    The Sleepy Bears  jazz                0
# 8            Flo Rida   pop          3750898
# 9       Kylie Minogue   pop          3152218
# 10         Jason Mraz   pop          3123738
# 11        Simple Plan   pop          2459606
# 12       Clean Bandit   pop          2193026
# 13      Nitumoni Pegu   pop                0
# 14      Prakash Rawat   pop                0
# 15  Remixing Mohit RM   pop                0
# 16         Sayar Bhai   pop                0
# 17             Tiësto   r&b          2920567
# 18        Chuck Berry   r&b          2311836
# 19      Mary J. Blige   r&b          2162433
# 20             ZZ Top   r&b          2014805
# 21             Brandy   r&b          1527232
# 22          The Doors  rock          4321093
# 23          Aerosmith  rock          4188927
# 24         Nickelback  rock          3855421
# 25       Joy Division  rock          3044840
# 26     Lynyrd Skynyrd  rock          2951381
#
#                                             Biography  \
# 0   Louis Armstrong (August 4, 1901 - July 6, 1971...
# 1   Ella Jane Fitzgerald (April 25, 1917 – June 15...
# 2   Dean Martin (born Dino Paul Crocetti; June 7, ...
# 3   Ray Charles (Ray Charles Robinson,  Albany, Ge...
# 4   Otis Ray Redding Jr. (September 9, 1941 – Dece...
# 5                                             No data
# 6                                             No data
# 7                                             No data
# 8   Tramar Dillard (born September 17, 1979 in Mia...
# 9   Kylie Ann Minogue is an Australian singer, son...
# 10  Jason Thomas Mraz (born June 23, 1977 in Mecha...
# 11  Simple Plan are a pop punk band from Montréal,...
# 12  Clean Bandit are a British electronic group fo...
# 13                                            No data
# 14                                            No data
# 15                                            No data
# 16                                            No data
# 17  Tijs Michiel Verwest, known professionally as ...
# 18  Charles Edward Anderson "Chuck" Berry (October...
# 19  Mary Jane Blige (born January 11, 1971 in Bron...
# 20  ZZ Top is a hard rock band formed in 1969 in H...
# 21  Brandy Rayana Norwood, known professionally by...
# 22  The Doors were an American rock band which for...
# 23  Aerosmith were an American rock band formed in...
# 24  Nickelback is a Canadian rock band which forme...
# 25  Joy Division were a post-punk band formed in 1...
# 26  Lynyrd Skynyrd (pronounced /ˌlɛnərd ˈskɪnərd/ ...
#
#                                       Similar Artists
# 0   Benny Goodman, Duke Ellington, Ella Fitzgerald...
# 1   Billie Holiday, Dinah Washington, Ella Fitzger...
# 2   Bobby Darin, Frank Sinatra, Nat King Cole, Per...
# 3   Aretha Franklin, Etta James, Louis Armstrong, ...
# 4   Otis Redding & Carla Thomas, Percy Sledge, Sam...
# 5                                             No data
# 6                                             No data
# 7                                             No data
# 8   B.o.B, Far East Movement, Pitbull, Sean Kingst...
# 9   Cher, Dannii Minogue, Girls Aloud, Madonna, So...
# 10  Colbie Caillat, Daniel Powter, Jack Johnson, J...
# 11  All Time Low, Boys Like Girls, Good Charlotte,...
# 12  Calvin Harris, Jax Jones, Jonas Blue, Sigala, ...
# 13                                            No data
# 14                                            No data
# 15                                            No data
# 16                                            No data
# 17  Alesso, Armin van Buuren, David Guetta, Ferry ...
# 18  Bo Diddley, Carl Perkins, Eddie Cochran, Jerry...
# 19  Faith Evans, Keyshia Cole, Monica, Toni Braxto...
# 20  AC/DC, George Thorogood & The Destroyers, Lyny...
# 21  Aaliyah, Faith Evans, Janet Jackson, Monica, T...
# 22  Cream, Jim Morrison, Jimi Hendrix, Led Zeppeli...
# 23  Alice Cooper, Bon Jovi, Guns N' Roses, Kiss, V...
# 24  3 Doors Down, Daughtry, Hinder, Shinedown, The...
# 25  Bauhaus, New Order, Siouxsie and the Banshees,...
# 26  Blackfoot, Molly Hatchet, The Allman Brothers ...

# %%
#-- VI. ¿Qué canciones tienen distintas versiones en la BBDD y en qué géneros aparecen?

def different_versions_songs():
    conn = mysql_conn()
    # 2. iniciamos el cursor   
    cursor = conn.cursor()

    # 3. query:
    query = ("""SELECT
                    s.song_name,
                    GROUP_CONCAT(DISTINCT a.artist_name SEPARATOR ', ') AS artist,
                    GROUP_CONCAT(DISTINCT s.genre SEPARATOR ', ') AS genre
                FROM songs AS s
                INNER JOIN artist AS a USING(id_artist)
                GROUP BY s.song_name
                HAVING COUNT(DISTINCT s.genre) > 1;
                                                """)

    # 4. luego llamamos al método execute() del cursor, al que pasamos como argumento el string que contiene la consulta.
    # De esta manera se ejecuta la consulta en la base de datos y si todo va correctamente, el resultado se almacenará en el cursor.
    cursor.execute(query)

    results = cursor.fetchall()
    cursor.close()
    conn.close()

    df_results = pd.DataFrame(results)
    df_results.columns = ['Song Name', 'Artist Name', 'Genre']
    return df_results

# %%
different_versions_songs()
# Out:
#                                Song Name  \
# 0                            All My Life
# 1                                Batalha
# 2                 Can't Find My Way Home
# 3      December, 1963 (Oh What a Night!)
# 4   I Can't Tell the Bottom from the Top
# 5                I Get a Kick Out of You
# 6                                  Intro
# 7                         It's Christmas
# 8                                   Lady
# 9                         Little Darlin'
# 10                       Time After Time
# 11                  Tumbling Tumbleweeds
# 12                      Wheel of Fortune
#
#                                           Artist Name           Genre
# 0         Ivory Joe Hunter, James Moody, Sweaty Palms      jazz, rock
# 1                                            Carranca       r&b, rock
# 2                                        Bonnie Raitt       r&b, rock
# 3                    Frankie Valli & The Four Seasons        pop, r&b
# 4                                         The Hollies       r&b, rock
# 5                           Bobby Solo, Matt Belsante       jazz, pop
# 6   Best Intentions, Hollow Da Don, Pihlanne, Taweh G  jazz, pop, r&b
# 7                                               Pilot       pop, rock
# 8                                 Eric Benét, Jay Jay        pop, r&b
# 9                           Jimmy Heath, Tommy Steele      jazz, rock
# 10                                        Lloyd Price       r&b, rock
# 11  Frank Ifield, Glen Gray & The Casa Loma Orchestra      jazz, rock
# 12               Johnny Hartman, The Hollywood Flames       jazz, r&b

# %%
#-- VII. ¿Qué artista tiene más canciones en la BBDD?

def most_songs_artist():
    conn = mysql_conn()
    # 2. iniciamos el cursor   
    cursor = conn.cursor()

    # 3. query:
    query = ("""SELECT
                    artist_name,
                    COUNT(id_song) AS total_songs
                FROM artist
                INNER JOIN songs USING(id_artist)
                GROUP BY artist_name
                HAVING total_songs >1
                ORDER BY total_songs DESC
                LIMIT 1;
                                                """)

    # 4. luego llamamos al método execute() del cursor, al que pasamos como argumento el string que contiene la consulta.
    # De esta manera se ejecuta la consulta en la base de datos y si todo va correctamente, el resultado se almacenará en el cursor.
    cursor.execute(query)

    results = cursor.fetchall()
    cursor.close()
    conn.close()

    df_results = pd.DataFrame(results)

    print(f'The artist with the most songs in our database is {df_results.iloc[0, 0]} with {df_results.iloc[0, 1]} songs ')

# %%
most_songs_artist()
# Out:
# The artist with the most songs in our database is Late Night Jazz Lounge with 18 songs

# %%
#-- VIII. ¿Cuántas canciones por género tenemos en nuestra base de datos?

def songs_by_genre():
    conn = mysql_conn()
    # 2. iniciamos el cursor   
    cursor = conn.cursor()

    # 3. query:
    query = ("""SELECT genre, COUNT(DISTINCT id_song) AS total_songs
                FROM songs
                GROUP BY genre
                ORDER BY total_songs DESC;
                                                """)

    # 4. luego llamamos al método execute() del cursor, al que pasamos como argumento el string que contiene la consulta.
    # De esta manera se ejecuta la consulta en la base de datos y si todo va correctamente, el resultado se almacenará en el cursor.
    cursor.execute(query)

    results = cursor.fetchall()
    cursor.close()
    conn.close()

    df_results = pd.DataFrame(results)
    df_results.columns = ['Genre', 'Total Songs']
    return df_results

# %%
songs_by_genre()
# Out:
#   Genre  Total Songs
# 0  jazz          564
# 1   pop          559
# 2  rock          543
# 3   r&b          525

# %%
#-- IX. ¿Qué artistas aparecen más veces como "artista similar" de otros artistas?

def most_similar_artists():
    conn = mysql_conn()
    # 2. iniciamos el cursor   
    cursor = conn.cursor()

    # 3. query:
    query = ("""SELECT sa.similar_artist, COUNT(*) AS times_similar
                FROM similar_artists sa
                GROUP BY sa.similar_artist
                ORDER BY times_similar DESC
                LIMIT 10;
                                                """)

    # 4. luego llamamos al método execute() del cursor, al que pasamos como argumento el string que contiene la consulta.
    # De esta manera se ejecuta la consulta en la base de datos y si todo va correctamente, el resultado se almacenará en el cursor.
    cursor.execute(query)

    results = cursor.fetchall()
    cursor.close()
    conn.close()

    df_results = pd.DataFrame(results)
    df_results.columns = ['Similar Artist', 'Times Similar']
    return df_results

# %%
most_similar_artists()
# Out:
#       Similar Artist  Times Similar
# 0    Neelkamal Singh             18
# 1  Khesari Lal Yadav             16
# 2         Shilpi Raj             14
# 3        Samar Singh             11
# 4             Monica             10
# 5     Java Jazz Cafe             10
# 6     Big Joe Turner              9
# 7        Lloyd Price              9
# 8     Wynonie Harris              8
# 9      Cafe Jazz Duo              8

# %%
#-- X.  Ranking de artistas por género, clasificados en 3 grupos según cantidad de listeners

def artist_by_genre():
    conn = mysql_conn()
    # 2. iniciamos el cursor   
    cursor = conn.cursor()

    # 3.query:
    query = ("""SELECT
                artist_name,
                genre,
                listeners,
                group_popularity          
                FROM (
                SELECT
                    genre,
                    artist_name,
                    listeners,
                    group_popularity,
                    ROW_NUMBER() OVER (
                        PARTITION BY genre, group_popularity
                        ORDER BY listeners DESC
                    ) AS rn
                FROM (
                    SELECT
                        s.genre,
                        a.artist_name,
                        MAX(a.listeners) AS listeners,  -- O SUM(a.listeners) si quieres sumar
                        CASE
                            WHEN MAX(a.listeners) >= 50000 THEN 'Most listened'
                            WHEN MAX(a.listeners) >= 10000 THEN 'Average'
                            ELSE 'Least listened'
                        END AS group_popularity
                    FROM songs s
                    JOIN artist a ON s.id_artist = a.id_artist
                    GROUP BY s.genre, a.artist_name
                ) grouped
            ) ranked
            WHERE rn <= 3
            ORDER BY genre, group_popularity, listeners DESC;
                                                """)

    # 4. luego llamamos al método execute() del cursor, al que pasamos como argumento el string que contiene la consulta.
    # De esta manera se ejecuta la consulta en la base de datos y si todo va correctamente, el resultado se almacenará en el cursor.
    cursor.execute(query)

    results = cursor.fetchall()
    cursor.close()
    conn.close()

    df_results = pd.DataFrame(results)
    df_results.columns = ['Artist Name','Genre', 'Listeners' ,'Group Popularity']
    return df_results

# %%
artist_by_genre()
# Out:
#           Artist Name Genre  Listeners Group Popularity
# 0      Ellis Marsalis  jazz      49411          Average
# 1        Chuck Willis  jazz      47227          Average
# 2          Scrimshire  jazz      46339          Average
# 3   Jazz For Sleeping  jazz       9921   Least listened
# 4       Bruno Spoerri  jazz       9696   Least listened
# 5      Victor Feldman  jazz       9627   Least listened
# 6     Louis Armstrong  jazz    2712606    Most listened
# 7     Ella Fitzgerald  jazz    2642994    Most listened
# 8         Dean Martin  jazz    2567892    Most listened
# 9        Connie Smith   pop      48374          Average
# 10         Sexy Sadie   pop      47749          Average
# 11            Marisol   pop      46683          Average
# 12       Olivia Lewis   pop       9824   Least listened
# 13        Pawan Singh   pop       9050   Least listened
# 14               inch   pop       7556   Least listened
# 15           Flo Rida   pop    3750898    Most listened
# 16      Kylie Minogue   pop    3152218    Most listened
# 17         Jason Mraz   pop    3123738    Most listened
# 18       Marv Johnson   r&b      49462          Average
# 19       Ewan MacColl   r&b      49406          Average
# 20       Smiley Lewis   r&b      49107          Average
# 21             J-Shin   r&b       9715   Least listened
# 22           Baby Gas   r&b       9570   Least listened
# 23  Não pode Ser Nada   r&b       9271   Least listened
# 24             Tiësto   r&b    2920567    Most listened
# 25        Chuck Berry   r&b    2311836    Most listened
# 26      Mary J. Blige   r&b    2162433    Most listened
# 27              TOTEM  rock      49106          Average
# 28      Sonny Burgess  rock      48134          Average
# 29            Canyons  rock      46363          Average
# 30   Boxhead Ensemble  rock       9957   Least listened
# 31            Bulldog  rock       9930   Least listened
# 32      Kemal Monteno  rock       9755   Least listened
# 33          The Doors  rock    4321093    Most listened
# 34          Aerosmith  rock    4188927    Most listened
# 35         Nickelback  rock    3855421    Most listened
